# %% [markdown]
# <a href="https://colab.research.google.com/github/juanluserra/master_bigdata/blob/main/hbase/sesion6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NoSQL (HBase) (sesión 6)

# %% [markdown]
# ![hbase-logo.e139b77f7031062f738f0fc28210e0ffa6ca26c8.png](data:image/png;base64,...)

# %% [markdown]
# Esta hoja muestra cómo acceder a bases de datos HBase y también a conectar la salida con Jupyter.
#
# Se puede utilizar el *shell* propio de HBase en la máquina virtual.
#
# Con HBase vamos a simular un modo _semi-clúster_ con una sola máquina.

# %%
RunningInCOLAB = 'google.colab' in str(get_ipython()) if hasattr(__builtins__,'__IPYTHON__') else False

# %%
# %%sh
# sudo apt-get update -qq
# sudo apt-get install -qq -y p7zip default-jdk
# Out:
# Selecting previously unselected package default-jre-headless.
# (Reading database ... 123630 files and directories currently installed.)
# Preparing to unpack .../00-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../01-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../02-openjdk-11-jre_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../03-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package default-jdk-headless.
# Preparing to unpack .../04-default-jdk-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jdk-headless (2:1.11-72build2) ...
# Selecting previously unselected package openjdk-11-jdk:amd64.
# Preparing to unpack .../05-openjdk-11-jdk_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jdk:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jdk.
# Preparing to unpack .../06-default-jdk_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jdk (2:1.11-72build2) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../07-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../08-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../09-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../10-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../11-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../12-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../13-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../14-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../15-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../16-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../17-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up default-jdk-headless (2:1.11-72build2) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up openjdk-11-jdk:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up default-jdk (2:1.11-72build2) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 18.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:

# %%
# Search for the first java interpreter. This code should work. If not, adjust JAVA_HOME manually.
import os
from pathlib import Path

def find_java_home() -> str | None:
  p  = Path('/usr/lib/jvm')
  (_, dirs, _) = next(os.walk(p))
  for d in dirs:
    inner_java: Path = p / d / 'bin' / 'java'
    if inner_java.is_file():
        return str(p.joinpath(d).absolute())
  return None

JAVA_HOME: str | None = os.getenv('JAVA_HOME', find_java_home())

# %%
# %env JAVA_HOME=$JAVA_HOME
# Out:
# env: JAVA_HOME=/usr/lib/jvm/java-1.11.0-openjdk-amd64

# %%
# %pip install bs4 lxml
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (5.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.6)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
# Determinar qué versión 2.x de HBase es la más reciente.
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re
from re import Pattern, Match

version_re: Pattern = re.compile(r'^(2\.[0-9]+(\.[0-9]+)?)')
req = Request("https://downloads.apache.org/hbase/")
html_page = urlopen(req)

soup = BeautifulSoup(html_page)

bigger2x = '2.0.0'  # Base version 2.x.x
for link in soup.findAll('a'):
  mresult: Match | None = version_re.match(link.get_text())
  if mresult and mresult.group(0) > bigger2x:
    bigger2x: str = mresult.group(0)

# %%
# %env HBASE_VERSION=$bigger2x
# Out:
# env: HBASE_VERSION=2.6.1

# %%
# %%bash
# wget -q https://downloads.apache.org/hbase/$HBASE_VERSION/hbase-$HBASE_VERSION-bin.tar.gz -O - | tar zxf -

# %%
# %%bash
# hbase-$HBASE_VERSION/bin/start-hbase.sh
# hbase-$HBASE_VERSION/bin/hbase-daemon.sh restart thrift
# Out:
# running master, logging to /content/hbase-2.6.1/bin/../logs/hbase--master-cdd3305db3dc.out
# running thrift, logging to /content/hbase-2.6.1/bin/../logs/hbase--thrift-cdd3305db3dc.out
# running thrift, logging to /content/hbase-2.6.1/bin/../logs/hbase--thrift-cdd3305db3dc.out
# no thrift to stop because no pid file /tmp/hbase--thrift.pid
# running thrift, logging to /content/hbase-2.6.1/bin/../logs/hbase--thrift-cdd3305db3dc.out

# %%
from pprint import pprint as pp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# Usaremos la librería `happybase` para python. La cargamos a continuación y hacemos la conexión.

# %%
# %pip install git+https://github.com/python-happybase/happybase.git
# Out:
# Collecting git+https://github.com/python-happybase/happybase.git
#   Cloning https://github.com/python-happybase/happybase.git to /tmp/pip-req-build-2_bor7d5
#   Running command git clone --filter=blob:none --quiet https://github.com/python-happybase/happybase.git /tmp/pip-req-build-2_bor7d5
#   Resolved https://github.com/python-happybase/happybase.git to commit 656409902bd6d411950232d50ed541196e993760
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from happybase==1.2.0) (1.16.0)
# Collecting thriftpy2>=0.4 (from happybase==1.2.0)
#   Downloading thriftpy2-0.5.2.tar.gz (782 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.3/782.3 kB 20.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from happybase==1.2.0) (6.4.5)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.10/dist-packages (from thriftpy2>=0.4->happybase==1.2.0) (3.0.11)
# Collecting ply<4.0,>=3.4 (from thriftpy2>=0.4->happybase==1.2.0)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.7 MB/s eta 0:00:00
# Building wheels for collected packages: happybase, thriftpy2
#   Building wheel for happybase (setup.py) ... done
#   Created wheel for happybase: filename=happybase-1.2.0-py2.py3-none-any.whl size=26615 sha256=f2e9ca19d097973f28305113d66946b0901b0c15e7731be9f9ddb25ad5f1d527
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kl_t0bn5/wheels/64/51/d8/7245574adff0cf933c418f64bc29b983fc137154efcc781739
#   Building wheel for thriftpy2 (pyproject.toml) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.5.2-cp310-cp310-linux_x86_64.whl size=1749818 sha256=f9280cba678740575140ab1bde3fac7f4632a2a92c025328c49346a4262ae3f3
#   Stored in directory: /root/.cache/pip/wheels/90/28/5f/279788e86e2eaccb3edc73bde9c815a9527602739a56344ff7
# Successfully built happybase thriftpy2
# Installing collected packages: ply, thriftpy2, happybase
# Successfully installed happybase-1.2.0 ply-3.11 thriftpy2-0.5.2

# %% [markdown]
# La conexión con la BD dura pocos segundos abierta porque está pensada para que un programa se conecte, haga una consulta y se desconecte. Al estar en una sesión interactiva, construyo un objeto `Connection` que genera un pool de conexiones. Si se desconecta, prueba otra vez.

# %%
from collections.abc import Generator
import happybase
from happybase import ConnectionPool
from contextlib import contextmanager
import os

HBASEHOST: str = os.getenv('HBASEHOST', 'localhost')

class Connection():

    def __init__(self, host: str):
        self.host: str = host
        self._genpool()

    def _genpool(self):
        self.pool = ConnectionPool(size=5, host=self.host)

    @contextmanager
    def connection(self) -> Generator[happybase.Connection, None, None]:
        for _ in range(5): # Probar 5 veces a regenerar el pool
            for _ in range(5): # Probar 5 veces a conectar
                with self.pool.connection() as connection:
                    try:
                        connection.tables()
                        yield connection
                        return
                    except Exception as _:
                        pass
            self._genpool()
        raise Exception("HBase Connection Error")

# %%
hbasecon = Connection(HBASEHOST)

# %%
with hbasecon.connection() as connection:
    print(connection.tables())
# Out:
# []

# %% [markdown]
# Para la carga inicial, vamos a crear todas las tablas con una única familia de columnas, `rawdata`, donde meteremos toda la información _raw_ comprimida. Después podremos hacer reorganizaciones de los datos para hacer el acceso más eficiente. Es una de las muchas ventajas de no tener un esquema.

# %%
# Create tables
tables: list[str] = ['posts', 'votes', 'users', 'tags', 'comments']
for t in tables:
    try:
        with hbasecon.connection() as connection:
            connection.create_table(
                t,
                {
                    'rawdata': dict(max_versions=1,compression='GZ')
                })
    except Exception as e:
        print("Database already exists: {0}. {1}".format(t, e))
        pass
with hbasecon.connection() as connection:
    print(connection.tables())
# Out:
# [b'comments', b'posts', b'tags', b'users', b'votes']

# %% [markdown]
# Descarga de datos:

# %%
# %%bash
# (wget -q https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.001 -O - ;
#  wget -q https://github.com/dsevilla/bd2-data/raw/main/es.stackoverflow/es.stackoverflow.csv.7z.002 -O - ) > es.stackoverflow.csv.7z

# %%
# %%bash
# 7zr x -aoa es.stackoverflow.csv.7z
# rm -rf es.stackoverflow.csv.7z
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 200457538 bytes (192 MiB)
#
# Extracting archive: es.stackoverflow.csv.7z
# --
# Path = es.stackoverflow.csv.7z
# Type = 7z
# Physical Size = 200457538
# Headers Size = 248
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Files: 5
# Size:       1044736301
# Compressed: 200457538

# %%
# !head Users.csv
# Out:
# Id,AboutMe,AccountId,CreationDate,DisplayName,DownVotes,LastAccessDate,Location,Reputation,UpVotes,Views,WebsiteUrl
# -1,"<p>Hola, no soy una persona real.</p><br/><br/><p>¡Soy un proceso que ayuda a mantener el sitio limpio!</p><br/><br/><p>Hago cosas como:</p><br/><br/><ul><br/><li>Dar empujoncitos a preguntas antiguas sin respuesta aproximadamente cada hora, para que atraigan algo de atención.</li><br/><li>Tener la propiedad de las preguntas y respuestas wiki para que nadie se lleve reputación por ellas</li><br/><li>Recibir la propiedad de los votos negativos en las publicaciones de spam o dañinas que son borradas permanentemente</li><br/><li>Tener la propiedad de las ediciones sugeridas por usuarios anónimos</li><br/><li><a href=""http://meta.stackoverflow.com/a/92006"">Quitar preguntas abandonadas</a></li><br/></ul><br/>",-1,2015-10-26T21:36:24.767,Comunidad,22504,2015-10-26T21:36:24.767,en la granja de servidores,1,10211,2516,
# 1,"<p>Dev #2 who helped create Stack Overflow currently working at Microsoft. I love all people willing to share their knowledge. Without community we are nothing.</p><br/><p>Find me on:</p><br/><p><a href=""http://www.twitter.com/SuperDalgas"" rel=""nofollow noreferrer"">Twitter</a><br/><br><br><br/><a href=""http://blog.stackoverflow.com/2009/05/welcome-stack-overflow-valued-associate-00003/"">Stack Overflow Valued Associate #00003</a></p><br/>",2,2015-10-26T22:50:12.710,Geoff Dalgas,0,2021-01-05T19:45:26.807,"Corvallis, OR",101,0,2917,http://stackoverflow.com
# 2,"<p>developer, techie, nerd.... ex-DBRE at Stack Overflow, previously a Community Manager for Stack Overflow.  When I'm not at my desk, I do CrossFit and run (a lot).</p><br/>",188123,2015-10-26T22:51:07.007,Taryn,0,2020-08-18T17:39:10.693,Arizona,101,0,109,https://tarynpivots.com
# 3,"<p>Topics you might be interested in reading about:</p><br/><ul><br/><li><a href=""https://jlericson.com/2023/10/16/catija.html"" rel=""nofollow noreferrer"">why Stack Exchange Inc undervalues community managers</a></li><br/><li><a href=""https://jlericson.com/tag/strike"" rel=""nofollow noreferrer"">the moderator strike</a></li><br/><li><a href=""https://jlericson.com/tag/documentation"" rel=""nofollow noreferrer"">documentation</a></li><br/><li><a href=""https://jlericson.com/tag/support"" rel=""nofollow noreferrer"">customer support</a></li><br/></ul><br/><p>I'm Head of Community at <a href=""https://talk.collegeconfidential.com/"" rel=""nofollow noreferrer"">College Confidential</a> and former <a href=""https://jlericson.com/2021/04/30/developer_advocate.html"" rel=""nofollow noreferrer"">Developer Advocate at EDB</a>. Stack Exchange no longer employs me as a <a href=""http://blog.stackoverflow.com/2013/08/please-welcome-jon-ericson-community-manager/"">Community Manager</a>.  I maintain an <a href=""http://chat.meta.stackexchange.com/rooms/738/jons-java-jitter-joint"">office on chat</a>. (Please ignore the meta cruft.)</p><br/><blockquote><br/><p><a href=""https://www.mechon-mamre.org/p/pt/pt2685.htm"" rel=""nofollow noreferrer"">Mercy and truth are met together; righteousness and peace have kissed each other.</a></p><br/></blockquote><br/><p>I write about my experience as a community manager at <a href=""https://jlericson.com/"" rel=""nofollow noreferrer"">jlericson.com</a>. You can read about what I've done over the years in my <a href=""https://web.archive.org/web/20220113195358/https://stackoverflow.com/users/story/1438"" rel=""nofollow noreferrer"" title=""Not guaranteed to be current.""><em>curriculum vitae</em></a>.</p><br/><p>On a personal note, I'm married and have three children.  Our oldest son loves school, friends, games, and music. Two of my children happen to have been born on the same day.  I <a href=""http://taking1and1.wordpress.com/"" rel=""nofollow noreferrer"" title=""Yet another half-assed blog."">sometimes write</a> about that experience. My wife loves taking care of people as a registered nurse and an all around wonderful person.</p><br/><p>Don't have time for a full review of something?  Why not try <a href=""http://fivesecondreview.wordpress.com/"" rel=""nofollow noreferrer"" title=""All reviews accurate and helpful or your money back."">my 5-second reviews</a>?</p><br/><p>I once wrote for <a href=""http://christianity.blogoverflow.com/author/jonericson/"" rel=""nofollow noreferrer"" title=""I haven't been on the rotation for a while, however."">Eschewmenical</a>, which was an experiment of <a href=""http://christianity.stackexchange.com/"">Christianity Stack Exchange</a>. For <em>a lot more</em> writing about the Bible, see <a href=""https://hermeneutics.stackexchange.com/users/68/jon-ericson?tab=summary"">my Biblical Hermeneutics posts</a>.</p><br/><br/>",1083,2015-10-26T22:52:12.923,Jon 'links in bio' Ericson,0,2023-06-04T23:58:02.373,Downtown Burbank,101,0,87,https://jlericson.com/
# 4,"<p>Lover of all things sharp including pencils, wit, and knives but not cheddar.</p><br/>",6254215,2015-10-26T23:18:40.547,Juan M,0,2022-02-11T16:07:18.457,Behind the Glass,101,56,260,
# 5,"<p>I am a Principal Software Engineer at Microsoft working on Azure Functions and related hosting technologies. Formerly the Architecture Lead for Stack Overflow where my day job consisted of being a Developer, Site Reliability Engineer, and DBA.</p><br/><p>I design and build very fast things in hopes of making life easier for millions of developers.</p><br/><p>Blog: <a href=""https://nickcraver.com/blog/"" rel=""nofollow noreferrer"">nickcraver.com/blog</a><br /><br/>Twitter: <a href=""https://twitter.com/Nick_Craver"" rel=""nofollow noreferrer"">@Nick_Craver</a><br /><br/>My Developer Story: <a href=""https://stackoverflow.com/story/ncraver"">stackoverflow.com/story/ncraver</a></p><br/><p><sub>Disclaimer: I have <em>no idea</em> what I'm talking about, all my answers are guesses!</sub></p><br/>",7598,2015-10-26T23:46:20.807,Nick Craver,0,2019-04-02T20:05:34.147,"Winston-Salem, NC",101,0,53,https://nickcraver.com/blog/
# 6,"<p>Chief Technical Officer at <a href=""https://postop.ai"" rel=""nofollow noreferrer"">https://postop.ai</a>.</p><br/><ul><br/><li>Stack Overflow Contributor since 2008</li><br/><li>Skeptics mod since 2011</li><br/><li>Core dev since March 2013</li><br/><li>Stack Overflow alumnus since February 2017</li><br/></ul><br/><p>You can find me on</p><br/><ul><br/><li><a href=""http://sklivvz.com"" rel=""nofollow noreferrer"">Personal site</a></li><br/><li><a href=""https://mastodon.social/@sklivvz"" rel=""nofollow noreferrer"">Mastodon</a></li><br/><li><a href=""https://github.com/sklivvz"" rel=""nofollow noreferrer"">Github</a></li><br/><li><a href=""https://www.linkedin.com/in/sklivvz/"" rel=""nofollow noreferrer"">LinkedIn</a></li><br/></ul><br/>",4623,2015-10-26T23:57:13.187,Sklivvz,0,2017-11-04T17:02:40.430,"Trento, Province of Trento, Italy",101,0,40,https://sklivvz.com
# 7,"<p><a href=""http://blog.stackoverflow.com/2013/09/summer-hiring-happened-so-fast/"">I'm</a> a Web Developer on the Stack Overflow Q&A Core <a href=""http://stackexchange.com/about/team"">team</a>. You can email me via sprelog (at) stackoverflow.com</p><br/>",51875,2015-10-27T07:03:55.417,m0sa,0,2023-01-24T10:24:53.517,Slovenia,101,0,51,
# 8,"<p>My top interests here are:</p><br/><br/><ul><br/><li>Python</li><br/><li>Django</li><br/><li>Software security</li><br/></ul><br/><br/><p>In the past, I used <code>python</code> and <code>django</code> to develop a payment solution at <a href=""https://www.my-bee.fr/pro/"" rel=""nofollow noreferrer"">MyBee</a> - I'm glad they're still going strong today! I also worked at <a href=""http://scalr.com/"" rel=""nofollow noreferrer"">Scalr</a> as a Product Manager, and at <a href=""http://www.accenture.com/"" rel=""nofollow noreferrer"">Accenture</a> as a consultant on business / IT projects. Today, I'm Lead Backend Engineer at <a href=""https://aptible.com"" rel=""nofollow noreferrer"">Aptible</a>.</p><br/><br/><p>Personal email: <code>thomas@orozco.fr</code></p><br/>",467632,2015-10-27T08:25:59.317,Thomas Orozco,0,2017-03-14T23:25:52.540,"Paris, France",101,0,27,

# %% [markdown]
# ### Carga de los datos

# %% [markdown]
# El código de importación es siempre el mismo, ya que se coge la primera fila del CSV que contiene el nombre de las columnas y se utiliza para generar nombres de columnas dentro de la familia de columnas dada como parámetro. La función `csv_to_hbase()` acepta un fichero CSV a abrir, un nombre de tabla y una familia de columnas donde agregar las columnas del fichero CSV. En nuestro caso siempre va a ser `rawdata`.

# %%
import csv
from happybase import Table

def csv_to_hbase(file: str, tablename: str, column_family: str):
    with hbasecon.connection() as connection, open(file) as f:
        table: Table = connection.table(tablename)

        # La llamada csv.reader() crea un iterador sobre un fichero CSV
        reader = csv.reader(f, dialect='excel')

        # Se leen las columnas. Sus nombres se usarán para crear las diferentes columnas en la familia
        columns_str: list[str] = next(reader)
        columns: list[bytes] = [column_family.encode() + b':' + c.encode() for c in columns_str]

        with table.batch(batch_size=500) as b:
            for row in reader:
                # La primera columna se usará como Row Key
                b.put(row[0], dict(zip(columns[1:], row[1:])))

# %% [markdown]
# La carga de los datos tarda tiempo, por lo que se hace en parlelo y en segundo plano para que podamos continuar con el notebook. Se utiliza el paradigma de "futures", una abstracción que permite dejar pendiente una computación en segundo plano, y obtenerla finalmente, o esperar a que termine, preguntar de vez en cuando, etc.

# %%
from concurrent.futures import Future

futures: dict[str, Future | None] = {t: None for t in tables}

# %%
from collections.abc import Iterable
from concurrent.futures import ThreadPoolExecutor

def import_table(t):
  print(f"Importando tabla {t}...")
  csv_to_hbase(t.capitalize() + '.csv', t, 'rawdata')
  return True

def background_import_tables() -> Iterable[Future[bool]]:
  e = ThreadPoolExecutor(len(tables))
  _futures = map(lambda t: e.submit(import_table, t), tables)
  return _futures

if not any(futures.values()):
  futures = dict(zip(tables, background_import_tables()))
else:
  print(f"Futures running: {any(futures.values())}. If not running, put futures=None",
        " and try again. This is to prevent running several works in background.")
# Out:
# Importando tabla posts...
# Importando tabla votes...
# Importando tabla users...
# Importando tabla tags...
# Importando tabla comments...

# %% [markdown]
# La siguiente línea muestra los "futures" que todavía están ejecutándose. Cuando se haya importado todo, todos los futures pondrán su running a False. Mientras tanto podemos continuar con el resto del Notebook.

# %%
f"Futures running: {dict(zip(tables, [f.running() for f in futures.values()]))}."
# Out:
# "Futures running: {'posts': True, 'votes': True, 'users': True, 'tags': True, 'comments': True}."

# %%
# Si no se está ejecutando en Google Colab, esperar a que terminen los trabajos en segundo plano.

if not RunningInCOLAB:
  from concurrent.futures import as_completed
  for f in as_completed(futures.values()):
    f.result()

# %% [markdown]
# ### Consultas sencillas desde Python
#
# A continuación veremos algunas consultas sencillas desde python usando el API de `happybase`.

# %%
def posts() -> Table:
  with hbasecon.connection() as connection:
    return connection.table('posts')

# %% [markdown]
# Obtener el Post con `Id` 5. La orden más sencilla e inmediata de HBase es obtener una fila, opcionalmente limitando las columnas a mostrar:

# %%
posts().row(b'5',columns=[b'rawdata:Body'])
# Out:
# {b'rawdata:Body': b'<p>\xc2\xbfCu\xc3\xa1l es la forma m\xc3\xa1s eficiente de separar un string en <code>c++</code>? como el que se muestra en el c\xc3\xb3digo, el cual contiene espacios entre las palabras, este es el m\xc3\xa9todo que yo estoy usando actualmente.</p><br/><br/><pre><code>#include <iostream><br/>#include <sstream><br/><br/>int main(int argc, char** argv){<br/><br/>    std::string str("Texto para dividir");<br/>    std::istringstream isstream(str);<br/><br/>    while(!isstream.eof()){<br/><br/>        std::string tempStr;<br/><br/>        isstream >> tempStr;<br/><br/>        std::cout << tempStr << std::endl;<br/>    }<br/><br/>    return 0;<br/>}<br/></code></pre><br/>'}

# %% [markdown]
# El siguiente código permite mostrar de forma amigable las tablas extraídas de la base de datos en forma de diccionario:

# %%
# http://stackoverflow.com/a/30525061/62365
class DictTable(dict):
    # Overridden dict class which takes a dict in the form {'a': 2, 'b': 3},
    # and renders an HTML Table in IPython Notebook.
    def _repr_html_(self):
        htmltext = ["<table width=100%>"]
        for key, value in self.items():
            htmltext.append("<tr>")
            htmltext.append("<td>{0}</td>".format(key.decode('utf-8')))
            htmltext.append("<td>{0}</td>".format(value.decode('utf-8')))
            htmltext.append("</tr>")
        htmltext.append("</table>")
        return ''.join(htmltext)

# %%
# Muestra cómo queda la fila del Id del Post 5
DictTable(posts().row(b'5'))
# Out:
# {b'rawdata:AcceptedAnswerId': b'208',
#  b'rawdata:AnswerCount': b'7',
#  b'rawdata:Body': b'<p>\xc2\xbfCu\xc3\xa1l es la forma m\xc3\xa1s eficiente de separar un string en <code>c++</code>? como el que se muestra en el c\xc3\xb3digo, el cual contiene espacios entre las palabras, este es el m\xc3\xa9todo que yo estoy usando actualmente.</p><br/><br/><pre><code>#include <iostream><br/>#include <sstream><br/><br/>int main(int argc, char** argv){<br/><br/>    std::string str("Texto para dividir");<br/>    std::istringstream isstream(str);<br/><br/>    while(!isstream.eof()){<br/><br/>        std::string tempStr;<br/><br/>        isstream >> tempStr;<br/><br/>        std::cout << tempStr << std::endl;<br/>    }<br/><br/>    return 0;<br/>}<br/></code></pre><br/>',
#  b'rawdata:ClosedDate': b'',
#  b'rawdata:CommentCount': b'1',
#  b'rawdata:CommunityOwnedDate': b'',
#  b'rawdata:ContentLicense': b'CC BY-SA 3.0',
#  b'rawdata:CreationDate': b'2015-10-30T01:15:27.267',
#  b'rawdata:FavoriteCount': b'',
#  b'rawdata:LastActivityDate': b'2020-06-30T02:23:26.197',
#  b'rawdata:LastEditDate': b'2016-09-27T17:46:24.900',
#  b'rawdata:LastEditorDisplayName': b'',
#  b'rawdata:LastEditorUserId': b'729',
#  b'rawdata:OwnerDisplayName': b'',
#  b'rawdata:OwnerUserId': b'24',
#  b'rawdata:ParentId': b'',
#  b'rawdata:PostTypeId': b'1',
#  b'rawdata:Score': b'37',
#  b'rawdata:Tags': b'<c++><string>',
#  b'rawdata:Title': b"\xc2\xbfC\xc3\xb3mo separar las palabras que contiene un string en C++? 'Split '",
#  b'rawdata:ViewCount': b'37867'}

# %%
DictTable(posts().row(b'5',columns=[b'rawdata:AnswerCount',b'rawdata:AcceptedAnswerId']))
# Out:
# {b'rawdata:AcceptedAnswerId': b'208', b'rawdata:AnswerCount': b'7'}

# %% [markdown]
# Y también se puede recorrer como un diccionario normal (el `decode` se utiliza para convertir los valores binarios de la base de datos a una codificación UTF-8):

# %%
row = posts().row(b'5')
for key, value in row.items():
    print("Key = '%s', Value = '%s'" %(key,value.decode('utf-8')[:40]))
# Out:
# Key = 'b'rawdata:AcceptedAnswerId'', Value = '208'
# Key = 'b'rawdata:AnswerCount'', Value = '7'
# Key = 'b'rawdata:Body'', Value = '<p>¿Cuál es la forma más eficiente de se'
# Key = 'b'rawdata:ClosedDate'', Value = ''
# Key = 'b'rawdata:CommentCount'', Value = '1'
# Key = 'b'rawdata:CommunityOwnedDate'', Value = ''
# Key = 'b'rawdata:ContentLicense'', Value = 'CC BY-SA 3.0'
# Key = 'b'rawdata:CreationDate'', Value = '2015-10-30T01:15:27.267'
# Key = 'b'rawdata:FavoriteCount'', Value = ''
# Key = 'b'rawdata:LastActivityDate'', Value = '2020-06-30T02:23:26.197'
# Key = 'b'rawdata:LastEditDate'', Value = '2016-09-27T17:46:24.900'
# Key = 'b'rawdata:LastEditorDisplayName'', Value = ''
# Key = 'b'rawdata:LastEditorUserId'', Value = '729'
# Key = 'b'rawdata:OwnerDisplayName'', Value = ''
# Key = 'b'rawdata:OwnerUserId'', Value = '24'
# Key = 'b'rawdata:ParentId'', Value = ''
# Key = 'b'rawdata:PostTypeId'', Value = '1'
# Key = 'b'rawdata:Score'', Value = '37'
# Key = 'b'rawdata:Tags'', Value = '<c++><string>'
# Key = 'b'rawdata:Title'', Value = '¿Cómo separar las palabras que contiene '
# Key = 'b'rawdata:ViewCount'', Value = '37867'

# %% [markdown]
# Finalmente, también se puede recorrer toda la tabla estableciendo filtros, que se estudiarán después. Se utiliza la función `scan`. Se puede iterar con los parámetros `key` y `data`. Por ejemplo, calcular el tamaño máximo de la longitud del texto de los posts:
#
# **(OJO, es un ejemplo, no se debería hacer así)**

# %%
max_len: int = 0
for key, data in posts().scan(columns=[b'rawdata:Body']):
    cur_len: int = len(data[b'rawdata:Body'])
    if cur_len > max_len:
        max_len = cur_len

print("Máxima longitud: %s caracteres." % (max_len))
# Out:
# Máxima longitud: 38200 caracteres.

# %% [markdown]
# ### Construcción de estructuras anidadas
#
# Al igual que pasaba con MongoDB, las bases de datos NoSQL como en este caso HBase permiten almacenar estructuras de datos complejas. En nuestro caso vamos a agregar los comentarios de cada pregunta o respuesta (post) en columnas del mismo. Para ello, creamos una nueva familia de columnas `comments`.
#
# HBase es bueno para añadir columnas sencillas, por ejemplo que contengan un valor. Sin embargo, si queremos añadir objetos complejos, tenemos que jugar con la codificación de la familia de columnas y columna.
#
# Usaremos el shell porque `happybase` no permite alterar tablas ya creadas.
#
# En el `shell` de HBase pondremos lo siguiente:
#
# ```
# disable 'posts'
# alter 'posts', {NAME => 'comments', VERSIONS => 1}
# enable 'posts'
# ```
#
# Cada comentario que añadimos contiene, al menos:
#
# - un id único
# - un texto
# - un autor
# - etc.
#
# ¿Cómo se consigue meterlo en una única familia de columnas?
#
# Hay varias formas. La que usaremos aquí, añadiremos el **id** de cada comentario como parte del nombre de la columna. Por ejemplo, el comentario con Id 2000, generará las columnas:
#
# - `Id_2000` (valor 2000)
# - `UserId_2000`
# - `PostId_2000`
# - `Text_2000`
#
# con sus correspondientes valores. Así, todos los datos relativos al comentario con Id original 2000, estarán almacenados en todas las columnas que terminen en "`_2000`". La base de datos permite implementar filtros que nos permiten buscar esto de forma muy sencilla. Los veremos después.

# %%
# %%bash
#
# cat <<EOF | hbase-$HBASE_VERSION/bin/hbase shell
# disable 'posts'
# alter 'posts', {NAME => 'comments', VERSIONS => 1}
# enable 'posts'
# exit
# EOF
# Out:
# HBase Shell
# Use "help" to get list of supported commands.
# Use "exit" to quit this interactive shell.
# For Reference, please visit: http://hbase.apache.org/2.0/book.html#shell
# Version 2.6.1, r7ed50b4dd742269a78875fb32112215f831284ff, Wed Oct  9 10:33:23 UTC 2024
# Took 0.0118 seconds
# hbase:001:0> disable 'posts'
# Took 22.4866 seconds
# hbase:002:0> alter 'posts', {NAME => 'comments', VERSIONS => 1}
# Updating all regions with the new schema...
# All regions updated.
# Done.
# Took 1.3395 seconds
# hbase:003:0> enable 'posts'
# Took 0.6753 seconds
# hbase:004:0> exit

# %%
with hbasecon.connection() as connection:
    comments_table: Table = connection.table('comments')
    posts_table: Table = connection.table('posts')

    with posts_table.batch(batch_size=500) as bp:
        # Hacer un scan de la tabla
        for key, data in comments_table.scan():
            comment: dict = {b'comments:' + d.split(b':')[1] + b"_" + key : data[d]
                        for d in data.keys()}
            bp.put(data[b'rawdata:PostId'], comment)

# %%
# Muestra cómo queda la fila del Id del Post 5, de nuevo, después de añadir los comentarios
DictTable(posts().row(b'5'))
# Out:
# {b'comments:ContentLicense_1477': b'CC BY-SA 3.0',
#  b'comments:CreationDate_1477': b'2015-12-10T16:34:36.243',
#  b'comments:PostId_1477': b'5',
#  b'comments:Score_1477': b'3',
#  b'comments:Text_1477': b'Cuidado con usar espacios para separar palabras, hay varios idiomas (como chino) que no usan espacios. Incluso en idiomas con caracteres latinos hay palabras como parlez-vous francais? en el que no se usa el espacio como separador. ICU tiene una libreria genial para todos los casos. http://userguide.icu-project.org/boundaryanalysis',
#  b'comments:UserDisplayName_1477': b'',
#  b'comments:UserId_1477': b'718',
#  b'rawdata:AcceptedAnswerId': b'208',
#  b'rawdata:AnswerCount': b'7',
#  b'rawdata:Body': b'<p>\xc2\xbfCu\xc3\xa1l es la forma m\xc3\xa1s eficiente de separar un string en <code>c++</code>? como el que se muestra en el c\xc3\xb3digo, el cual contiene espacios entre las palabras, este es el m\xc3\xa9todo que yo estoy usando actualmente.</p><br/><br/><pre><code>#include <iostream><br/>#include <sstream><br/><br/>int main(int argc, char** argv){<br/><br/>    std::string str("Texto para dividir");<br/>    std::istringstream isstream(str);<br/><br/>    while(!isstream.eof()){<br/><br/>        std::string tempStr;<br/><br/>        isstream >> tempStr;<br/><br/>        std::cout << tempStr << std::endl;<br/>    }<br/><br/>    return 0;<br/>}<br/></code></pre><br/>',
#  b'rawdata:ClosedDate': b'',
#  b'rawdata:CommentCount': b'1',
#  b'rawdata:CommunityOwnedDate': b'',
#  b'rawdata:ContentLicense': b'CC BY-SA 3.0',
#  b'rawdata:CreationDate': b'2015-10-30T01:15:27.267',
#  b'rawdata:FavoriteCount': b'',
#  b'rawdata:LastActivityDate': b'2020-06-30T02:23:26.197',
#  b'rawdata:LastEditDate': b'2016-09-27T17:46:24.900',
#  b'rawdata:LastEditorDisplayName': b'',
#  b'rawdata:LastEditorUserId': b'729',
#  b'rawdata:OwnerDisplayName': b'',
#  b'rawdata:OwnerUserId': b'24',
#  b'rawdata:ParentId': b'',
#  b'rawdata:PostTypeId': b'1',
#  b'rawdata:Score': b'37',
#  b'rawdata:Tags': b'<c++><string>',
#  b'rawdata:Title': b"\xc2\xbfC\xc3\xb3mo separar las palabras que contiene un string en C++? 'Split '",
#  b'rawdata:ViewCount': b'37867'}

# %%
# !wget -q https://github.com/dsevilla/bdge-data/raw/master/wikipedia/eswiki.xml.gz

# %% [markdown]
# Se crea la tabla para albergar la `wikipedia`. Igual que la vista en teoría, pero aquí se usa `wikipedia` en vez de `wiki` para que no colisionen la versión completa con la reducida.

# %% [markdown]
# De nuevo en el `shell` de HBase:
#
# ```
# create 'wikipedia' , 'text', 'revision'
# disable 'wikipedia' # Para evitar su uso temporal
# alter 'wikipedia' , { NAME => 'text', VERSIONS => org.apache.hadoop.hbase.HConstants::ALL_VERSIONS }
# alter 'wikipedia' , { NAME => 'revision', VERSIONS => org.apache.hadoop.hbase.HConstants::ALL_VERSIONS }
# alter 'wikipedia' , { NAME => 'text', COMPRESSION => 'GZ', BLOOMFILTER => 'ROW'}
# enable 'wikipedia'
# ```

# %%
# %%bash
#
# cat <<EOF | hbase-$HBASE_VERSION/bin/hbase shell
# create 'wikipedia' , 'text', 'revision'
# disable 'wikipedia' # Para evitar su uso temporal
# alter 'wikipedia' , { NAME => 'text', VERSIONS => org.apache.hadoop.hbase.HConstants::ALL_VERSIONS }
# alter 'wikipedia' , { NAME => 'revision', VERSIONS => org.apache.hadoop.hbase.HConstants::ALL_VERSIONS }
# alter 'wikipedia' , { NAME => 'text', COMPRESSION => 'GZ', BLOOMFILTER => 'ROW'}
# enable 'wikipedia'
# exit
# EOF
# Out:
# HBase Shell
# Use "help" to get list of supported commands.
# Use "exit" to quit this interactive shell.
# For Reference, please visit: http://hbase.apache.org/2.0/book.html#shell
# Version 2.6.1, r7ed50b4dd742269a78875fb32112215f831284ff, Wed Oct  9 10:33:23 UTC 2024
# Took 0.0034 seconds
# hbase:001:0> create 'wikipedia' , 'text', 'revision'
# Created table wikipedia
# Took 1.7135 seconds
# => Hbase::Table - wikipedia
# hbase:002:0> disable 'wikipedia' # Para evitar su uso temporal
# Took 0.4733 seconds
# hbase:003:0> alter 'wikipedia' , { NAME => 'text', VERSIONS => org.apache.hadoop.hbase.HConstants::ALL_VERSIONS }
# Updating all regions with the new schema...
# All regions updated.
# Done.
# Took 1.2432 seconds
# hbase:004:0> alter 'wikipedia' , { NAME => 'revision', VERSIONS => org.apache.hadoop.hbase.HConstants::ALL_VERSIONS }
# Updating all regions with the new schema...
# All regions updated.
# Done.
# Took 1.0564 seconds
# hbase:005:0> alter 'wikipedia' , { NAME => 'text', COMPRESSION => 'GZ', BLOOMFILTER => 'ROW'}
# Updating all regions with the new schema...
# All regions updated.
# Done.
# Took 1.0619 seconds
# hbase:006:0> enable 'wikipedia'
# Took 0.6543 seconds
# hbase:007:0> exit

# %% [markdown]
# Este código, visto en teoría, recorre el árbol XML construyendo documentos y llamando a la función `callback` con cada uno. Los documentos son diccionarios con las claves encontradas dentro de los tags `<page>...</page>`.

# %%
import xml.sax
import re

class WikiHandler(xml.sax.handler.ContentHandler):

    def __init__(self):
        self._charBuffer = ''
        self.document = {}

    def _getCharacterData(self):
        data = self._charBuffer
        self._charBuffer = ''
        return data

    def parse(self, f, callback):
        self.callback = callback
        xml.sax.parse(f, self)

    def characters(self, data):
        self._charBuffer = self._charBuffer + data

    def startElement(self, name, attrs):
        if name == 'page':
        # print 'Start of page'
            self.document = {}
        if re.match(r'title|timestamp|username|comment|text', name):
            self._charBuffer = ''

    def endElement(self, name):
        if re.match(r'title|timestamp|username|comment|text', name):
            self.document[name] = self._getCharacterData()
            # print(name, ': ', self.document[name][:20])
        if 'revision' == name:
            self.callback(self.document)

# %% [markdown]
# El codigo a continuación, cada vez que el código anterior llama a la función `processdoc()` se añade un documento a la base de datos.

# %%
import time
import gzip

class FillWikiTable():
    """Llena la tabla Wiki"""
    def __init__(self,connection):
        # Conectar a la base de datos a través de Thrift
        self.table = connection.table('wikipedia')

    def run(_s):
        def processdoc(d):
            print("Callback called with {0}".format(d['title']))
            tuple_time = time.strptime(d['timestamp'], "%Y-%m-%dT%H:%M:%SZ")
            timestamp = int(time.mktime(tuple_time))
            _s.table.put(d['title'],
                         {'text:': d.get('text',''),
                          'revision:author': d.get('username',''),
                          'revision:comment': d.get('comment','')},
                         timestamp=timestamp)

        with gzip.open('eswiki.xml.gz','r') as f:
            start = time.time()
            WikiHandler().parse(f, processdoc)
            end = time.time()
            print ("End adding documents. Time: %.5f" % (end - start))

# %%
with hbasecon.connection() as connection:
    FillWikiTable(connection).run()
# Out:
# Callback called with Wikipedia:Artículos solicitados
# Callback called with Andorra
# Callback called with Argentina
# Callback called with Geografía de Andorra
# Callback called with Demografía de Andorra
# Callback called with Comunicaciones de Andorra
# Callback called with Artes visuales
# Callback called with Agricultura
# Callback called with Astronomía galáctica
# Callback called with ASCII
# Callback called with Arquitectura
# Callback called with Anoeta
# Callback called with Ana María Matute
# Callback called with Agujero negro
# Callback called with Anarquía
# Callback called with América del Norte
# Callback called with América del Sur
# Callback called with Asia
# Callback called with Año
# Callback called with Asaph Hall
# Callback called with Afganistán
# Callback called with Arqueología
# Callback called with Wikipedia:Anuncios
# Callback called with Commodore Amiga
# Callback called with Commodore Amiga 500
# Callback called with Francesc Aguilar Villalonga
# Callback called with Aquifoliaceae
# Callback called with Sapindaceae
# Callback called with Anacardiaceae
# Callback called with Autogiro
# Callback called with Albert Einstein
# Callback called with Araliales
# Callback called with Araliaceae
# Callback called with Apiaceae
# Callback called with Atmósfera de un cuerpo celeste
# Callback called with Archaeabacteria
# Callback called with Antipartícula
# Callback called with Araucariaceae
# Callback called with Arecidae
# Callback called with Ascomycota
# Callback called with Ajedrez
# Callback called with Aleksandr Beliavski
# Callback called with Aldehído
# Callback called with Alcaloide
# Callback called with Adeudo por domiciliación
# Callback called with Alfabeto griego
# Callback called with Circo
# Callback called with Año bisiesto
# Callback called with América
# Callback called with Agujero negro de Schwarzschild
# Callback called with Agujero negro de Einstein-Rosen
# Callback called with Agujero de gusano
# Callback called with Axón
# Callback called with Asteraceae
# Callback called with Alismataceae
# Callback called with Agavoideae
# Callback called with Amaryllidoideae
# Callback called with Aljarafe
# Callback called with Arecaceae
# Callback called with Araceae
# Callback called with Amperio
# Callback called with Antonio Vivaldi
# Callback called with Arthoniaceae
# Callback called with Astasia
# Callback called with Ada
# Callback called with Aromadendron
# Callback called with Alnus
# Callback called with Archaea
# Callback called with Allocasuarina
# Callback called with Alfaroa
# Callback called with Annamocarya sinensis
# Callback called with Alergia
# Callback called with Achmatherum
# Callback called with Aegilops
# Callback called with Aeluropus
# Callback called with Agropyron
# Callback called with Agrostis
# Callback called with Aira
# Callback called with Airopsis tenella
# Callback called with Alopecurus
# Callback called with Ammophila
# Callback called with Ampelodesmos
# Callback called with Andropogon
# Callback called with Anthoxanthum
# Callback called with Antinoria
# Callback called with Apera
# Callback called with Aristida
# Callback called with Arrhenatherum
# Callback called with Arundinaria
# Callback called with Arundo
# Callback called with Avellinia
# Callback called with Avena
# Callback called with Avenula blaui
# Callback called with Aciachne acicularis
# Callback called with Acroceras
# Callback called with Aegopogon
# Callback called with Anthephora
# Callback called with Arberella
# Callback called with AmigaOS
# Callback called with AGA
# Callback called with Sierra de Atapuerca
# Callback called with Arcoíris
# Callback called with Arte culinario
# Callback called with Alimento
# Callback called with Achlaena
# Callback called with Achneria
# Callback called with Achyrodes
# Callback called with Alvimia
# Callback called with Amphicarpum
# Callback called with Amphipogon
# Callback called with Avión
# Callback called with ALGOL
# Callback called with Wikipedia:Traducciones solicitadas
# Callback called with Alfabeto
# Callback called with Amstrad
# Callback called with Atlante
# Callback called with Anaximandro
# Callback called with Algoritmo de los códigos de redundancia cíclica
# Callback called with Algoritmo genético
# Callback called with Aniselytron
# Callback called with Apoclada simplex
# Callback called with Apocopis
# Callback called with Apogonia
# Callback called with Arctagrostis
# Callback called with Arthraxon
# Callback called with Arthrostylidium
# Callback called with Arundarbor
# Callback called with Arundinella
# Callback called with Arundoclaytonia
# Callback called with Atheropogon
# Callback called with Arthropogon
# Callback called with Atropis
# Callback called with Aulaxanthus
# Callback called with Aulonemia
# Callback called with Axonopus
# Callback called with Algoritmo
# Callback called with Automatic Repeat Request
# Callback called with Acarreo
# Callback called with Anaxímenes
# Callback called with Acamptoclados
# Callback called with Oware
# Callback called with Algoritmo de compresión con pérdida
# Callback called with Atlántida (desambiguación)
# Callback called with Alegoría
# Callback called with Aféresis (fonética)
# Callback called with Abreviatura
# Callback called with Acento léxico
# Callback called with Acróstico
# Callback called with Activa tantum
# Callback called with Caso acusativo
# Callback called with Adjetivo
# Callback called with Caso adlativo
# Callback called with Adstrato
# Callback called with Ala
# Callback called with Paisaje protegido de las Siete Lomas
# Callback called with AmigaDOS
# Callback called with Atletismo
# Callback called with Animalia
# Callback called with Autotrofo
# Callback called with Azalea
# Callback called with Acacia
# Callback called with Azur
# Callback called with Impatiens balsamina
# Callback called with Aldea
# Callback called with Anatomía
# Callback called with Anatomía humana
# Callback called with Arrianismo
# Callback called with Arte
# Callback called with Albania
# Callback called with Alemania
# Callback called with Angola
# Callback called with Antigua y Barbuda
# Callback called with Austria
# Callback called with Azerbaiyán
# Callback called with Anthony Quinn
# Callback called with Astronomía
# Callback called with Arte marcial
# Callback called with Antigüedad
# Callback called with Antigüedad clásica
# Callback called with Alquimia
# Callback called with Astrología
# Callback called with Asexual
# Callback called with Astorga
# Callback called with Alberta
# Callback called with Andalucía
# Callback called with Magnetorresistencia
# Callback called with Año 1900
# Callback called with Annonaceae
# Callback called with Advanced Interactive Executive
# Callback called with A fala
# Callback called with Astronomía infrarroja
# Callback called with Astronomía ultravioleta
# Callback called with Geografía de Alemania
# Callback called with Aquiles
# Callback called with Afrodita
# Callback called with Apolo
# Callback called with Actuación
# Callback called with Almedina
# Callback called with Atlas (desambiguación)
# Callback called with Albaida (Valencia)
# Callback called with Alicante
# Callback called with Agricultura ecológica
# Callback called with AtheOS
# Callback called with Automovilismo
# Callback called with Acrobatidae
# Callback called with Axiología
# Callback called with Actual rey de Francia
# Callback called with Adventismo
# Callback called with Adventista
# Callback called with Wikipedia:Bienvenidos
# Callback called with Batista (tejido)
# Callback called with Bonsái
# Callback called with Barión
# Callback called with Budismo
# Callback called with Big bang
# Callback called with Provincia de Burgos
# Callback called with Botánica
# Callback called with Bosón
# Callback called with Botánica pura
# Callback called with Botánica general
# Callback called with Botánica aplicada
# Callback called with Botánica especial
# Callback called with Botánica Sistemática
# Callback called with Brassicaceae
# Callback called with Begoniaceae
# Callback called with Bombacaceae
# Callback called with Bomba lógica
# Callback called with Bioquímica
# Callback called with Balanophoraceae
# Callback called with Buxaceae
# Callback called with Bases de Datos
# Callback called with Barias
# Callback called with Balsaminaceae
# Callback called with Baricentro
# Callback called with Baria
# Callback called with Bar (desambiguación)
# Callback called with Bosón de Higgs
# Callback called with Lámina beta
# Callback called with Bálsamo
# Callback called with Bernal Díaz del Castillo
# Callback called with Butomaceae
# Callback called with Base de datos
# Callback called with Betulaceae
# Callback called with Bellardiochloa
# Callback called with Brachiaria
# Callback called with Brachypodium
# Callback called with Bromus
# Callback called with Bambuseae
# Callback called with Baloncesto
# Callback called with BASIC
# Callback called with Bit
# Callback called with Blues
# Callback called with Borra
# Callback called with Bill Gates
# Callback called with Bit de redundancia
# Callback called with Beckera
# Callback called with Berghausia
# Callback called with Bothriochloa
# Callback called with Bouteloua
# Callback called with Bromidium
# Callback called with Brachyelytrum
# Callback called with Barcelona
# Callback called with BIOS
# Callback called with Barrapunto
# Callback called with Bougainvillea
# Callback called with Basílica de San Isidoro de León
# Callback called with Biblia
# Callback called with Biología molecular
# Callback called with Biblioteca
# Callback called with Casco Antiguo de León
# Callback called with Brasil
# Callback called with Evangelio de Lucas
# Callback called with Beethoven
# Callback called with Vergara
# Callback called with Bomba hidráulica
# Callback called with Bandera
# Callback called with Bellerophon
# Callback called with Bodhisattva
# Callback called with Billy Wilder
# Callback called with Buda
# Callback called with Bolero ranchero
# Callback called with Bacteria
# Callback called with Burramyidae
# Callback called with Ayuda:Cómo se edita una página
# Callback called with Ayuda:Cómo empezar una página
# Callback called with Wikipedia:Cómo Debe Llamarse La HomePage
# Callback called with Constelación
# Callback called with Cristalografia
# Callback called with Caliz
# Callback called with Corola
# Callback called with Caramelo
# Callback called with Provincia de Cádiz
# Callback called with Cracker
# Callback called with Crack
# Callback called with Organización Europea para la Investigación Nuclear
# Callback called with Colombia
# Callback called with Comunicación (desambiguación)
# Callback called with Código abierto
# Callback called with Ayuda:Caracteres especiales
# Callback called with Cine
# Callback called with Copyleft
# Callback called with Lenguas de Colombia
# Callback called with Sistema de gobierno de Colombia
# Callback called with Población de Colombia
# Callback called with Catolicismo
# Callback called with Wikipedia:Creación de enlaces externos
# Callback called with Cabotaje
# Callback called with Ciencias de la salud
# Callback called with Wikipedia:Contenidos
# Callback called with Wikipedia:Comentarios
# Callback called with Wikipedia:Wikipedia no es de papel
# Callback called with Ciencias de la Tierra
# Callback called with Cristianismo
# Callback called with C
# Callback called with Cinturon de kuiper
# Callback called with Cesio
# Callback called with Centímetro
# Callback called with Centímetro cúbico
# Callback called with Castilla y León
# Callback called with Cuadrado
# Callback called with Canarias
# Callback called with Comedia
# Callback called with Cinturón de asteroides
# Callback called with Comunidad Valenciana
# Callback called with Chincha Alta
# Callback called with Cuba
# Callback called with Clasificación de los organismos vegetales
# Callback called with Cecina
# Callback called with Cistaceae
# Callback called with Capparaceae
# Callback called with Brassicales
# Callback called with Crassulaceae
# Callback called with Caesalpiniaceae
# Callback called with Anexo:Calendario de aniversarios
# Callback called with Capsella bursa-pastoris
# Callback called with Cornales
# Callback called with Cornaceae
# Callback called with Ciato
# Callback called with Coriariaceae
# Callback called with Cneoraceae
# Callback called with Código de país
# Callback called with Castellano (desambiguación)
# Callback called with Cgs
# Callback called with Cfc
# Callback called with Cegesimal
# Callback called with Clorofluorocarburo
# Callback called with Centímetro cuadrado
# Callback called with Wikipedia:Chat y Foro de Wikipedistas
# Callback called with Cono
# Callback called with Cupressaceae
# Callback called with Cycadatae
# Callback called with CCC
# Callback called with Cycas revoluta
# Callback called with Camilo José Cela
# Callback called with Célula (desambiguación)
# Callback called with Cyperaceae
# Callback called with Commelinaceae
# Callback called with Crossings
# Callback called with Constante física
# Callback called with Cyanophyta
# Callback called with Cyclocarpales
# Callback called with Ciencias de la computación
# Callback called with Cryptophyta
# Callback called with Alga verde
# Callback called with Colacium
# Callback called with Ceratium
# Callback called with Castanea henryi
# Callback called with Castanea seguinii
# Callback called with Castanea crenata
# Callback called with Castanea ozarkensis
# Callback called with Castanea sativa
# Callback called with Célula fotoeléctrica
# Callback called with Célula madre
# Callback called with Célula nerviosa
# Callback called with Canica
# Callback called with Circunferencia
# Callback called with Crenarchaeota
# Callback called with Cycadeoidopsida
# Callback called with Casuarinaceae
# Callback called with Casuarina
# Callback called with Ceuthostoma
# Callback called with Carya
# Callback called with Cyclocarya paliurus
# Callback called with Calamogrostis
# Callback called with Catabrosa
# Callback called with Chaetopogon fasciculatus
# Callback called with Coix
# Callback called with Cortaderia
# Callback called with Corynephorus
# Callback called with Crypsis
# Callback called with Ctenopsis garcini
# Callback called with Cutandia
# Callback called with Cynodon
# Callback called with Cynosurus
# Callback called with Cobol
# Callback called with CODASYL
# Callback called with Ayuda:Imágenes
# Callback called with Commodore 64
# Callback called with Commodore 128
# Callback called with Cuarta generación de ordenadores
# Callback called with Código simbólico
# Callback called with Compilador
# Callback called with Cláusula de Horn
# Callback called with C++
# Callback called with Código hexadecimal
# Callback called with Código alfanumérico
# Callback called with Código de caracteres de 8 bits
# Callback called with Ciencia
# Callback called with Civilizacion
# Callback called with Command & Conquer
# Callback called with Constitución de 1812
# Callback called with Compresión de datos
# Callback called with Códigos fuente
# Callback called with Códigos Univocamente Decodificables
# Callback called with Cadmio
# Callback called with Carbono
# Callback called with Carl Sagan
# Callback called with Decimal codificado en binario
# Callback called with Coma fija
# Callback called with Coma flotante
# Callback called with Código de corrección de errores
# Callback called with Códigos de bloque
# Callback called with Civilization (serie)
# Callback called with Ciencia ficción
# Callback called with Verificación por redundancia cíclica
# Callback called with Códigos de Redundancia Cíclica
# Callback called with Cliente
# Callback called with Cometa
# Callback called with Wikipedia:Convención sobre copyright
# Callback called with Código unívocamente descodificable
# Callback called with Circuito de conmutación
# Callback called with Computador
# Callback called with Claude Elwood Shannon
# Callback called with Complex Instruction Set Computer
# Callback called with Cibercafé
# Callback called with Ciberlocal
# Callback called with Cyborg
# Callback called with Calamovilfa
# Callback called with Calderonella sylvatica
# Callback called with Calotheca
# Callback called with Campulosus
# Callback called with Caryochloa
# Callback called with Cathestechum
# Callback called with Cenchrus
# Callback called with Centotheca
# Callback called with Centrochloa sungularis
# Callback called with Cephalostachyum
# Callback called with Chaetochloa
# Callback called with Chamaeraphis hordeacea
# Callback called with Chikusichloa
# Callback called with Chloris
# Callback called with Chondrosium
# Callback called with Chrysopogon
# Callback called with Chusquea
# Callback called with Cinna
# Callback called with Clinelymus
# Callback called with Coelachne
# Callback called with Coelorachis
# Callback called with Colpodium
# Callback called with Cryptochloa
# Callback called with Cymbopogon
# Callback called with Chaetium
# Callback called with Wikipedia:Cómo hacer que las imágenes pesen poco
# Callback called with Wikipedia:Autorización Barrapunto
# Callback called with Biología celular
# Callback called with Wikipedia:Cómo mejorar el indice de temas de la Portada
# Callback called with Cordado
# Callback called with Cráneo
# Callback called with Cerebro
# Callback called with Cartilaginoso
# Callback called with Cartílago
# Callback called with Cerebelo
# Callback called with Complejo
# Callback called with Costa Rica
# Callback called with Contrato de compraventa
# Callback called with Go
# Callback called with Atari-Go
# Callback called with Clasificación de los jugadores de go
# Callback called with Candela
# Callback called with Lorenzo Cerdá
# Callback called with Colegio Hogwarts de Magia
# Callback called with Constitución
# Callback called with Clipper (lenguaje de programación)
# Callback called with Solenostemon
# Callback called with Cinetosis
# Callback called with Calathea
# Callback called with Ciudad
# Callback called with Catedral de León
# Callback called with Ciencias ocultas
# Callback called with Ciencias sociales
# Callback called with Cámara
# Callback called with Comunidad autónoma
# Callback called with Cartografía
# Callback called with Compositor
# Callback called with Cultura
# Callback called with Ciencias aplicadas
# Callback called with Clasificación (desambiguación)
# Callback called with Clase
# Callback called with Clasificación Unesco
# Callback called with Clasificación Unesco de 4 dígitos
# Callback called with Camino de Santiago
# Callback called with Clasificación Unesco de 6 dígitos
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/11 Lógica
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/12 Matemática
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/21 Astronomía y Astrofísica
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/22 Física
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/23 Química
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/24 Ciencias de la Vida
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/25 Ciencias de la Tierra y el Espacio
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/31 Ciencias Agronómicas
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/32 Ciencias Médicas
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/33 Ciencias de la tecnología
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/51 Antropología
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/52 Demografía
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/53 Ciencias de la economía
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/54 Geografía
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/55 Historia
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/56 Derecho
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/57 Lingüística
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/58 Pedagogía
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/59 Ciencias políticas
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/61 Psicología
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/62 Ciencias de las artes y las letras
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/63 Sociología
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/71 Ética
# Callback called with Wikipedia:Clasificación Unesco de 6 dígitos/72 Filosofía
# Callback called with Clasificación Decimal Universal
# Callback called with Cineasta
# Callback called with Citoplasma
# Callback called with Congregación
# Callback called with Cine de autor
# Callback called with Cine mudo
# Callback called with Cine sonoro
# Callback called with Climatología
# Callback called with Canadá
# Callback called with Wikipedia:Cómo comenzar
# Callback called with Catedral
# Callback called with Cáncer de mama
# Callback called with Conjunto
# Callback called with Cuento
# Callback called with Cubalibre
# Callback called with Cristalografía
# Callback called with Chiapas
# Callback called with Castilla-La Mancha
# Callback called with Caudofoveata
# Callback called with Cuzco
# Callback called with Calendario
# Callback called with Ciudad Real (Provincia)
# Callback called with Crustacea
# Callback called with CARO
# Callback called with Chilena (género musical)
# Callback called with Charles Darwin
# Callback called with Ciclo de Krebs
# Callback called with Ciclope
# Callback called with Cianobacteria
# Callback called with Cuaterniones
# Callback called with Fotografía tradicional
# Callback called with Coco Chanel
# Callback called with Daphne
# Callback called with Deporte
# Callback called with Don Quijote de la Mancha
# Callback called with Debian GNU/Linux
# Callback called with Unidad de disco duro
# Callback called with Denia
# Callback called with Densidad
# Callback called with Didáctica
# Callback called with Día
# Callback called with Dalái lama
# Callback called with Danza
# Callback called with Danzas afroperuanas
# Callback called with Anexo:Diferencias de léxico entre países de lengua española
# Callback called with Dilleniidae
# Callback called with Derecho
# Callback called with Dominio público
# Callback called with Ayuda:Interfaz de Wikipedia
# Callback called with Droseraceae
# Callback called with Dina (unidad de medida)
# Callback called with Declaración Schuman
# Callback called with Día europeo
# Callback called with Disciplinas auxiliares usadas en historia
# Callback called with Distancia
# Callback called with Dendrita
# Callback called with Dioscoreaceae
# Callback called with Dermatocarpaceae
# Callback called with Discolichenes
# Callback called with Dinophyta
# Callback called with Dinophyceae
# Callback called with Desmophycidae
# Callback called with Dinophycidae
# Callback called with Phytodinales
# Callback called with Dinocapsales
# Callback called with Dinotricales
# Callback called with Dugandiodendron
# Callback called with Dactylis
# Callback called with Danthonia
# Callback called with Deschampsia
# Callback called with Desmazeria
# Callback called with Dichanthium
# Callback called with Digitaria
# Callback called with Disfunción sexual
# Callback called with Dolina
# Callback called with Wikipedia:Convenciones idiomáticas
# Callback called with Demolición
# Callback called with Derecho constitucional
# Callback called with Diamante
# Callback called with Detección y corrección de errores
# Callback called with Distancia de Hamming
# Callback called with Dune
# Callback called with Demiurgo
# Callback called with Dios
# Callback called with Dragón
# Callback called with Dactyloctenium
# Callback called with Dendrocalamus
# Callback called with Dendrochloa distans
# Callback called with Deyeuxia
# Callback called with Diandrolyra
# Callback called with Dimeria
# Callback called with Dimorphostachys
# Callback called with Dinochloa
# Callback called with Diplachne
# Callback called with Distichlis
# Callback called with Ayuda:Uso de LaTeX
# Callback called with Signo diacrítico
# Callback called with Douglas Rushkoff
# Callback called with Coerción
# Callback called with Dualismo
# Callback called with Wikipedia:Declaración de Larry Sanger acerca de la bifurcación de la enciclopedia wiki en Castellano
# Callback called with Dietas
# Callback called with Dionaea muscipula
# Callback called with Derecho procesal civil
# Callback called with Darwin (sistema operativo)
# Callback called with Dasyuromorphia
# Callback called with Distribuciones LIVE
# Callback called with Dasyuridae
# Callback called with Didelphidae
# Callback called with Diprotodontia
# Callback called with Estambre
# Callback called with Electrónica de potencia
# Callback called with España
# Callback called with Exploit
# Callback called with Educación
# Callback called with EV
# Callback called with Electronvoltio
# Callback called with Electrónica
# Callback called with Ernesto Sabato
# Callback called with Geografía de España
# Callback called with Economía de España
# Callback called with Política de España
# Callback called with Idiomas de España
# Callback called with Historia de España
# Callback called with Estadística
# Callback called with Estocástico
# Callback called with Enciclopedia
# Callback called with Electromagnetismo
# Callback called with Entropía (desambiguación)
# Callback called with Energía (tecnología)
# Callback called with Espín
# Callback called with Economía
# Callback called with Elegía
# Callback called with Epopeya
# Callback called with Entremés
# Callback called with Ensamblador
# Callback called with Electricidad
# Callback called with Elipse
# Callback called with Euskal-Herria
# Callback called with Euskal Herria
# Callback called with El modelo de Pickman
# Callback called with Europa
# Callback called with Ecología
# Callback called with Especie
# Callback called with Euro
# Callback called with Eneas
# Callback called with Ebenaceae
# Callback called with Empetraceae
# Callback called with Ericaceae
# Callback called with Ericales
# Callback called with Elaterio
# Callback called with Euphorbiales
# Callback called with Euphorbiaceae
# Callback called with Época Histórica
# Callback called with Erythroxylaceae
# Callback called with Epifanía
# Callback called with Estructura secundaria de las proteínas
# Callback called with Estructura terciaria de las proteínas
# Callback called with Estructura cuaternaria de las proteínas
# Callback called with Etología
# Callback called with Ephedraceae
# Callback called with Esperanto
# Callback called with Efecto túnel
# Callback called with Equisetidae
# Callback called with Idioma español
# Callback called with Enero
# Callback called with Entretenimiento
# Callback called with Ecósfera
# Callback called with Euglena
# Callback called with Erytropsis
# Callback called with Equipo terminal de datos
# Callback called with ETCD
# Callback called with Equidistante
# Callback called with Euryarchaeota
# Callback called with Echinochloa
# Callback called with Elymus
# Callback called with Eragrostis
# Callback called with Esfera
# Callback called with Etimología
# Callback called with Esmeralda
# Callback called with Eatonia
# Callback called with Ekmanochloa
# Callback called with Eleusine
# Callback called with Elionurus
# Callback called with Elymordeum montanense
# Callback called with Elyonurus
# Callback called with Enteropogon
# Callback called with Epicampes
# Callback called with Eremochloa
# Callback called with Eriachne
# Callback called with Erianthus
# Callback called with Eriochloa
# Callback called with Eriocoma
# Callback called with Euchlaena
# Callback called with Eulalia
# Callback called with Eustachys
# Callback called with Esqueleto humano
# Callback called with Encéfalo
# Callback called with Epigrafía
# Callback called with Escritura acrofonética
# Callback called with Ergonomía
# Callback called with Egipto
# Callback called with Ethernet
# Callback called with Erupciones históricas de Tenerife
# Callback called with Escalada
# Callback called with Espacio vectorial
# Callback called with Epaminondas (juego)
# Callback called with Epistemología jurídica
# Callback called with Eric S. Raymond
# Callback called with Escudo
# Callback called with Enlazador
# Callback called with Etiología
# Callback called with Exégesis
# Callback called with Evangelio
# Callback called with Estado
# Callback called with Espectáculo
# Callback called with Esotérico
# Callback called with Enfermería
# Callback called with Enfermedad de Alzheimer
# Callback called with Enfermedad de Bright
# Callback called with Enfermedad de Parkinson
# Callback called with Ecumenismo
# Callback called with Eléctrica
# Callback called with Exploraciones europeas de Oceanía
# Callback called with Extremadura
# Callback called with Eolo
# Callback called with Edad Media
# Callback called with Emulador
# Callback called with Espeleología
# Callback called with Ernst Lubitsch
# Callback called with Energía Eólica
# Callback called with Revista electrónica
# Callback called with Epicúreos
# End adding documents. Time: 5.85064

# %% [markdown]
# El código a continuación permite ver las diferentes versiones de una revisión. Como la versión reducida es muy pequeña no da lugar a que haya ninguna revisión, pero con este código se vería. Hace uso del _shell_ de HBase:
#
# ```
# get 'wikipedia', 'Commodore Amiga', {COLUMN => 'revision',VERSIONS=>10}
# ```

# %%
with hbasecon.connection() as connection:
    wikipedia = connection.table('wikipedia')
    for key,data in wikipedia.scan(columns=['revision'], row_start='A', row_stop='B', limit=10):
        print(key,'->',data)
# Out:
# b'A fala' -> {b'revision:author': b'KLBot2', b'revision:comment': b'Bot: Cambiando #REDIRECT por #REDIRECCI\xc3\x93N.'}
# b'AGA' -> {b'revision:author': b'Savh', b'revision:comment': b'Savh movi\xc3\xb3 la p\xc3\xa1gina [[AGA (desambiguaci\xc3\xb3n)]] a [[AGA]]: Solicitado'}
# b'ALGOL' -> {b'revision:author': b'G\xc3\xbcnniX', b'revision:comment': b'/* Enlaces externos y bibliograf\xc3\xada */'}
# b'ASCII' -> {b'revision:author': b'', b'revision:comment': b''}
# b'Abreviatura' -> {b'revision:author': b'', b'revision:comment': b'/* Diccionarios de abreviaturas */'}
# b'Acacia' -> {b'revision:author': b'Jkbw', b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/212.55.25.241|212.55.25.241]] ([[User talk:212.55.25.241|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Jkbw'}
# b'Acamptoclados' -> {b'revision:author': b'KLBot2', b'revision:comment': b'Bot: Cambiando #REDIRECT por #REDIRECCI\xc3\x93N.'}
# b'Acarreo' -> {b'revision:author': b'Farisori', b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/~Expresses life|~Expresses life]] ([[User talk:~Expresses life|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Farisori'}
# b'Acento l\xc3\xa9xico' -> {b'revision:author': b'CEM-bot', b'revision:comment': b'Peque\xc3\xb1as correcciones [[WP:CEM]].'}
# b'Achlaena' -> {b'revision:author': b'KLBot2', b'revision:comment': b'Bot: Cambiando #REDIRECT por #REDIRECCI\xc3\x93N.'}

# %% [markdown]
# La siguiente consulta no poduce resultados. ¿Por qué?

# %%
with hbasecon.connection() as connection:
    wikipedia = connection.table('wikipedia')
    for key,data in wikipedia.scan(columns=['revision'], row_start='A', row_stop='C',
                                   filter="PrefixFilter('B')",
                                   limit=10):
        print (key,'->',data)
# Out:
# b'BASIC' -> {b'revision:author': b'Benjavalero', b'revision:comment': b'Correcciones ortogr\xc3\xa1ficas'}
# b'BIOS' -> {b'revision:author': b'PatruBOT', b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/79.153.162.34|79.153.162.34]] ([[User talk:79.153.162.34|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Mansoncc'}
# b'Bacteria' -> {b'revision:author': b'Technopat', b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/181.57.143.98|181.57.143.98]] ([[User talk:181.57.143.98|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Osado'}
# b'Balanophoraceae' -> {b'revision:author': b'', b'revision:comment': b''}
# b'Baloncesto' -> {b'revision:author': b'Balles2601', b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/64.32.117.118|64.32.117.118]] ([[User talk:64.32.117.118|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Wiki LIC'}
# b'Balsaminaceae' -> {b'revision:author': b'Elvisor', b'revision:comment': b'Bot:Reparando enlaces'}
# b'Bambuseae' -> {b'revision:author': b'RoRo', b'revision:comment': b''}
# b'Bandera' -> {b'revision:author': b'Bernard', b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/Mariiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii|Mariiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii]] ([[User talk:Mariiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...'}
# b'Bar (desambiguaci\xc3\xb3n)' -> {b'revision:author': b'B25es', b'revision:comment': b'/* Lugares */'}
# b'Barcelona' -> {b'revision:author': b'', b'revision:comment': b''}

# %% [markdown]
# ## En los siguientes ejercicios, usando `happybase`, utiliza o bien `scan` o bien `row` donde sea conveniente:

# %% [markdown]
# ## EJERCICIO: Mostrar la familia de columnas `revision` para la entrada `ASCII` de la tabla `wikipedia`.

# %%
with hbasecon.connection() as connection:
    wikipedia = connection.table('wikipedia')
    row_data = wikipedia.row(b'ASCII', columns=[b'revision'])
    for key, data in row_data.items():
        print(key,'->',data)
# Out:
# b'revision:author' -> b''
# b'revision:comment' -> b''

# %% [markdown]
# ## EJERCICIO: Mostrar las 20 primeras filas de la tabla `wikipedia` cuyas columnas empiecen por 'com'.

# %%
with hbasecon.connection() as connection:
    wikipedia = connection.table('wikipedia')
    for key, data in wikipedia.scan(limit=20, filter="ColumnPrefixFilter('com')"):
        print(key, '->', data)
# Out:
# b'A fala' -> {b'revision:comment': b'Bot: Cambiando #REDIRECT por #REDIRECCI\xc3\x93N.'}
# b'AGA' -> {b'revision:comment': b'Savh movi\xc3\xb3 la p\xc3\xa1gina [[AGA (desambiguaci\xc3\xb3n)]] a [[AGA]]: Solicitado'}
# b'ALGOL' -> {b'revision:comment': b'/* Enlaces externos y bibliograf\xc3\xada */'}
# b'ASCII' -> {b'revision:comment': b''}
# b'Abreviatura' -> {b'revision:comment': b'/* Diccionarios de abreviaturas */'}
# b'Acacia' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/212.55.25.241|212.55.25.241]] ([[User talk:212.55.25.241|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Jkbw'}
# b'Acamptoclados' -> {b'revision:comment': b'Bot: Cambiando #REDIRECT por #REDIRECCI\xc3\x93N.'}
# b'Acarreo' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/~Expresses life|~Expresses life]] ([[User talk:~Expresses life|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Farisori'}
# b'Acento l\xc3\xa9xico' -> {b'revision:comment': b'Peque\xc3\xb1as correcciones [[WP:CEM]].'}
# b'Achlaena' -> {b'revision:comment': b'Bot: Cambiando #REDIRECT por #REDIRECCI\xc3\x93N.'}
# b'Achmatherum' -> {b'revision:comment': b'Bot: Cambiando #REDIRECT por #REDIRECCI\xc3\x93N.'}
# b'Achneria' -> {b'revision:comment': b'Redirigiendo a \xc2\xab[[Eriachne]]\xc2\xbb'}
# b'Achyrodes' -> {b'revision:comment': b'Bot: Cambiando #REDIRECT por #REDIRECCI\xc3\x93N.'}
# b'Aciachne acicularis' -> {b'revision:comment': b'Bot: [[m:User:Invadibot/scope#eswiki|8]] - Estandarizaciones y otras mejoras automatizadas'}
# b'Acrobatidae' -> {b'revision:comment': b'A\xc3\xb1adiendo la [[Categor\xc3\xada:Familias de mam\xc3\xadferos]] mediante [[Wikipedia:HotCat|HotCat]]'}
# b'Acroceras' -> {b'revision:comment': b'/* Taxonom\xc3\xada */ ; ortograf\xc3\xada'}
# b'Acr\xc3\xb3stico' -> {b'revision:comment': b''}
# b'Activa tantum' -> {b'revision:comment': b'Robot: Arreglando doble redirecci\xc3\xb3n \xe2\x86\x92 [[Anexo:Locuciones latinas]]'}
# b'Actuaci\xc3\xb3n' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/41.219.27.75|41.219.27.75]] ([[User talk:41.219.27.75|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de HermanHn'}
# b'Actual rey de Francia' -> {b'revision:comment': b'Cambios menores.'}

# %% [markdown]
# ## EJERCICIO: Mostrar las 20 primeras filas de la tabla `wikipedia` cuyas columnas empiecen por 'com' y la clave de fila empieza por 'B'.

# %%
with hbasecon.connection() as connection:
  wikipedia = connection.table("wikipedia")
  doc = wikipedia.scan(limit=20, filter="ColumnPrefixFilter('com')", row_start=b'B')
  for key,data in doc:
    print(key, '->', data)
# Out:
# b'BASIC' -> {b'revision:comment': b'Correcciones ortogr\xc3\xa1ficas'}
# b'BIOS' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/79.153.162.34|79.153.162.34]] ([[User talk:79.153.162.34|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Mansoncc'}
# b'Bacteria' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/181.57.143.98|181.57.143.98]] ([[User talk:181.57.143.98|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Osado'}
# b'Balanophoraceae' -> {b'revision:comment': b''}
# b'Baloncesto' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/64.32.117.118|64.32.117.118]] ([[User talk:64.32.117.118|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de Wiki LIC'}
# b'Balsaminaceae' -> {b'revision:comment': b'Bot:Reparando enlaces'}
# b'Bambuseae' -> {b'revision:comment': b''}
# b'Bandera' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/Mariiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii|Mariiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii]] ([[User talk:Mariiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...'}
# b'Bar (desambiguaci\xc3\xb3n)' -> {b'revision:comment': b'/* Lugares */'}
# b'Barcelona' -> {b'revision:comment': b''}
# b'Baria' -> {b'revision:comment': b''}
# b'Barias' -> {b'revision:comment': b'Automated conversion'}
# b'Baricentro' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/187.190.21.99|187.190.21.99]] ([[User talk:187.190.21.99|disc.]]) ([[WP:HG|HG]]) (3.1.21)'}
# b'Bari\xc3\xb3n' -> {b'revision:comment': b''}
# b'Barrapunto' -> {b'revision:comment': b'/* Historia */'}
# b'Base de datos' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/186.86.10.179|186.86.10.179]] ([[User talk:186.86.10.179|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de PatruBOT'}
# b'Bases de Datos' -> {b'revision:comment': b''}
# b'Bas\xc3\xadlica de San Isidoro de Le\xc3\xb3n' -> {b'revision:comment': b'Revertidos los cambios de [[Special:Contributions/176.85.110.123|176.85.110.123]] ([[User talk:176.85.110.123|disc.]]) a la \xc3\xbaltima edici\xc3\xb3n de 176.83.15.9'}
# b'Batista (tejido)' -> {b'revision:comment': b''}
# b'Beckera' -> {b'revision:comment': b'Redirigiendo a \xc2\xab[[Snowdenia]]\xc2\xbb'}

# %% [markdown]
# ## EJERCICIO: Mostrar sólo la columna `revision:author` de las filas de la tabla `wikipedia` cuya clave empiece por `a` y termine por `a` (obviando mayúsculas y minúsculas).

# %%
with hbasecon.connection() as connection:
  wikipedia = connection.table("wikipedia")
  filter_str = "RowFilter(=,'regexstring:^[aA].*[aA]$')"
  doc = wikipedia.scan(columns=[b"revision:author"], filter=filter_str)
  for key,data in doc:
    print(key, '->', data)
# Out:
# b'A fala' -> {b'revision:author': b'KLBot2'}
# b'AGA' -> {b'revision:author': b'Savh'}
# b'Abreviatura' -> {b'revision:author': b''}
# b'Acacia' -> {b'revision:author': b'Jkbw'}
# b'Achlaena' -> {b'revision:author': b'KLBot2'}
# b'Achneria' -> {b'revision:author': b'MILEPRI'}
# b'Actual rey de Francia' -> {b'revision:author': b'CEM-bot'}
# b'Ada' -> {b'revision:author': b'Solbaken'}
# b'Adventista' -> {b'revision:author': b'Benjavalero'}
# b'Afrodita' -> {b'revision:author': b'Foundling'}
# b'Agricultura' -> {b'revision:author': b'Foundling'}
# b'Agricultura ecol\xc3\xb3gica' -> {b'revision:author': b'Lin linao'}
# b'Aira' -> {b'revision:author': b'BenjaBot'}
# b'Airopsis tenella' -> {b'revision:author': b'BenjaBot'}
# b'Ala' -> {b'revision:author': b'Shooke'}
# b'Albania' -> {b'revision:author': b''}
# b'Alberta' -> {b'revision:author': b'Alexandra Desir\xc3\xa9e Reyes'}
# b'Aldea' -> {b'revision:author': b'4lextintor'}
# b'Alegor\xc3\xada' -> {b'revision:author': b'Arjuno3'}
# b'Alemania' -> {b'revision:author': b'Arjuno3'}
# b'Alergia' -> {b'revision:author': b'Jkbw'}
# b'Alfaroa' -> {b'revision:author': b'Macofe'}
# b'Algoritmo de compresi\xc3\xb3n con p\xc3\xa9rdida' -> {b'revision:author': b'Elvisor'}
# b'Algoritmo de los c\xc3\xb3digos de redundancia c\xc3\xadclica' -> {b'revision:author': b'Albertojuanse'}
# b'Allocasuarina' -> {b'revision:author': b'Elvisor'}
# b'Almedina' -> {b'revision:author': b'PascualTorres'}
# b'Alquimia' -> {b'revision:author': b'Xabier'}
# b'Alvimia' -> {b'revision:author': b'BenjaBot'}
# b'Ammophila' -> {b'revision:author': b'BenjaBot'}
# b'Am\xc3\xa9rica' -> {b'revision:author': b'Eduardosalg'}
# b'Anarqu\xc3\xada' -> {b'revision:author': b''}
# b'Anatom\xc3\xada' -> {b'revision:author': b'Jcfidy'}
# b'Anatom\xc3\xada humana' -> {b'revision:author': b'LMLM'}
# b'Andaluc\xc3\xada' -> {b'revision:author': b'PatruBOT'}
# b'Andorra' -> {b'revision:author': b'Juamax'}
# b'Anexo:Diferencias de l\xc3\xa9xico entre pa\xc3\xadses de lengua espa\xc3\xb1ola' -> {b'revision:author': b''}
# b'Angola' -> {b'revision:author': b'Jacinto-Mir\xc3\xb3briga'}
# b'Animalia' -> {b'revision:author': b'Jarould'}
# b'Anoeta' -> {b'revision:author': b'Benjavalero'}
# b'Anthephora' -> {b'revision:author': b'Misigon'}
# b'Antigua y Barbuda' -> {b'revision:author': b''}
# b'Antig\xc3\xbcedad cl\xc3\xa1sica' -> {b'revision:author': b'UA31'}
# b'Antinoria' -> {b'revision:author': b'BenjaBot'}
# b'Antipart\xc3\xadcula' -> {b'revision:author': b''}
# b'Apera' -> {b'revision:author': b'BenjaBot'}
# b'Apogonia' -> {b'revision:author': b'MILEPRI'}
# b'Arberella' -> {b'revision:author': b'MILEPRI'}
# b'Archaea' -> {b'revision:author': b'HakanIST'}
# b'Archaeabacteria' -> {b'revision:author': b'KLBot2'}
# b'Argentina' -> {b'revision:author': b'FARCROSX'}
# b'Aristida' -> {b'revision:author': b'BenjaBot'}
# b'Arqueolog\xc3\xada' -> {b'revision:author': b'Dorieo'}
# b'Arquitectura' -> {b'revision:author': b'LMLM'}
# b'Arundinaria' -> {b'revision:author': b'Elvisor'}
# b'Arundinella' -> {b'revision:author': b'MILEPRI'}
# b'Arundoclaytonia' -> {b'revision:author': b'BenjaBot'}
# b'Ascomycota' -> {b'revision:author': b'Bruno Rene Vargas'}
# b'Asia' -> {b'revision:author': b'Eduardosalg'}
# b'Astasia' -> {b'revision:author': b'Franciscosp2'}
# b'Astorga' -> {b'revision:author': b'Deutsch Alc\xc3\xa1ntara'}
# b'Astrolog\xc3\xada' -> {b'revision:author': b'Foundling'}
# b'Astronom\xc3\xada' -> {b'revision:author': b'Alejandrocaro35'}
# b'Astronom\xc3\xada gal\xc3\xa1ctica' -> {b'revision:author': b''}
# b'Astronom\xc3\xada infrarroja' -> {b'revision:author': b'Benjavalero'}
# b'Astronom\xc3\xada ultravioleta' -> {b'revision:author': b'Legobot'}
# b'Aulonemia' -> {b'revision:author': b'Invadibot'}
# b'Austria' -> {b'revision:author': b''}
# b'Avellinia' -> {b'revision:author': b'BenjaBot'}
# b'Avena' -> {b'revision:author': b'BallenaBlanca'}
# b'Axiolog\xc3\xada' -> {b'revision:author': b'Fixertool'}
# b'Ayuda:C\xc3\xb3mo empezar una p\xc3\xa1gina' -> {b'revision:author': b'Jrodriguezvillalobos'}
# b'Ayuda:C\xc3\xb3mo se edita una p\xc3\xa1gina' -> {b'revision:author': b'AnselmiJuan'}
# b'Ayuda:Interfaz de Wikipedia' -> {b'revision:author': b'Erne Mogilevich'}
# b'Azalea' -> {b'revision:author': b''}

# %% [markdown]
# ## EJERCICIO: Mostrar las filas de la tabla `users` (sólo la columna `rawdata:Location`) de usuarios de España (se supondrá que su localización (columna `rawdata:Location`) contiene `España` o `ES`, obviando mayúsculas y minúsculas).

# %%
with hbasecon.connection() as connection:
    users = connection.table('users')
    filter = "ValueFilter(=, 'regexstring:(?i)(^|\W)ES(\W|$)') OR ValueFilter(=, 'regexstring:(?i)(^|\W)España(\W|$)')"
    doc = users.scan(columns=["rawdata:Location"], filter=filter)
    for key,data in doc:
        print(key, "->", data)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# b'14249' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'142522' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'142560' -> {b'rawdata:Location': b'Castell\xc3\xb3, Espa\xc3\xb1a'}
# b'142592' -> {b'rawdata:Location': b'Santander, Cantabria, Espa\xc3\xb1a'}
# b'142593' -> {b'rawdata:Location': b'Santander, Espa\xc3\xb1a'}
# b'142617' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'142627' -> {b'rawdata:Location': b'Basque Country, Espa\xc3\xb1a'}
# b'142655' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'142710' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'142720' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'142721' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'142726' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'142744' -> {b'rawdata:Location': b'Santander, Cantabria, Espa\xc3\xb1a'}
# b'142803' -> {b'rawdata:Location': b'Empuriabrava, Girona, Espa\xc3\xb1a'}
# b'142858' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'142867' -> {b'rawdata:Location': b'Pamplona, Espa\xc3\xb1a'}
# b'14288' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'14293' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'142981' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'143013' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'143020' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143119' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'143258' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'143277' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143300' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143331' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'143334' -> {b'rawdata:Location': b'Oviedo, Espa\xc3\xb1a'}
# b'143335' -> {b'rawdata:Location': b'Tenerife, Espa\xc3\xb1a'}
# b'143339' -> {b'rawdata:Location': b'Almussafes, Espa\xc3\xb1a'}
# b'143349' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'14336' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143361' -> {b'rawdata:Location': b'Santander, Espa\xc3\xb1a'}
# b'143365' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'143379' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'143485' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'143502' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'143506' -> {b'rawdata:Location': b'Lorca, Espa\xc3\xb1a'}
# b'143510' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'143513' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143528' -> {b'rawdata:Location': b'Lucena, Espa\xc3\xb1a'}
# b'143533' -> {b'rawdata:Location': b'Santander, Espa\xc3\xb1a'}
# b'143551' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'143624' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'143628' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'143631' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143642' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'143649' -> {b'rawdata:Location': b'Galicia, Espa\xc3\xb1a'}
# b'143651' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'143696' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'143712' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'143726' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'143764' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'143769' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143771' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143772' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143785' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'143835' -> {b'rawdata:Location': b'Lanzarote, Espa\xc3\xb1a'}
# b'14389' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'143898' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143903' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'143912' -> {b'rawdata:Location': b'Vigo, Espa\xc3\xb1a'}
# b'143956' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'143963' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'143967' -> {b'rawdata:Location': b'La Laguna, Espa\xc3\xb1a'}
# b'144028' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'144147' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'144148' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'144182' -> {b'rawdata:Location': b'Calle Isaac Peral, Santander, Espa\xc3\xb1a'}
# b'144189' -> {b'rawdata:Location': b'Reus, Espa\xc3\xb1a'}
# b'144194' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'144204' -> {b'rawdata:Location': b'Fuensalida, Espa\xc3\xb1a'}
# b'144241' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'144313' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'144318' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'144326' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'144332' -> {b'rawdata:Location': b'Alcal\xc3\xa1 de Henares, Espa\xc3\xb1a'}
# b'144337' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'144368' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'144406' -> {b'rawdata:Location': b'Santiago de Compostela, Espa\xc3\xb1a'}
# b'144430' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'144513' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'144533' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'144545' -> {b'rawdata:Location': b'Ciudad Real, Espa\xc3\xb1a'}
# b'144583' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'144775' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'144798' -> {b'rawdata:Location': b'Cervell\xc3\xb3, Barcelona, Espa\xc3\xb1a'}
# b'144991' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'144992' -> {b'rawdata:Location': b'C\xc3\xa1ceres, Espa\xc3\xb1a'}
# b'144994' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'144997' -> {b'rawdata:Location': b'Tenerife, Santa Cruz de Tenerife, Espa\xc3\xb1a'}
# b'145082' -> {b'rawdata:Location': b'Almer\xc3\xada, Espa\xc3\xb1a'}
# b'145085' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145087' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145104' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'145176' -> {b'rawdata:Location': b'Jerez de la Frontera, Espa\xc3\xb1a'}
# b'145203' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'145208' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'145352' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145357' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'14536' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'145362' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'145375' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'14539' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'145390' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145498' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'145509' -> {b'rawdata:Location': b'Gij\xc3\xb3n, Espa\xc3\xb1a'}
# b'145514' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'145548' -> {b'rawdata:Location': b'Tarragona, Espa\xc3\xb1a'}
# b'145630' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'145682' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145730' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'145805' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'14587' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145900' -> {b'rawdata:Location': b'Valladolid, Espa\xc3\xb1a'}
# b'145920' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145950' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145961' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'145986' -> {b'rawdata:Location': b'Ourense, Espa\xc3\xb1a'}
# b'145997' -> {b'rawdata:Location': b'Baza, Espa\xc3\xb1a'}
# b'146001' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146033' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'146085' -> {b'rawdata:Location': b'Ourense, Espa\xc3\xb1a'}
# b'1461' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146130' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'146134' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146140' -> {b'rawdata:Location': b'UAH - Escuela Polit\xc3\xa9cnica, Alcal\xc3\xa1 de Henares, Espa\xc3\xb1a'}
# b'14615' -> {b'rawdata:Location': b'Asturias, Espa\xc3\xb1a'}
# b'146160' -> {b'rawdata:Location': b'Santander, Espa\xc3\xb1a'}
# b'146231' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'146236' -> {b'rawdata:Location': b'Valladolid, Espa\xc3\xb1a'}
# b'146252' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146253' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'146278' -> {b'rawdata:Location': b'Terrassa, Espa\xc3\xb1a'}
# b'146371' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'146373' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146383' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146384' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'146409' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146413' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146434' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'146551' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'146568' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'14657' -> {b'rawdata:Location': b'08830 Sant Boi de Llobregat, Espa\xc3\xb1a'}
# b'14671' -> {b'rawdata:Location': b'30180 Bullas, Espa\xc3\xb1a'}
# b'146889' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146969' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'146983' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'147040' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'147050' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'147052' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'147071' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'147076' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'147093' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'147136' -> {b'rawdata:Location': b'San Sebasti\xc3\xa1n, Espa\xc3\xb1a'}
# b'147148' -> {b'rawdata:Location': b'Valladolid, Espa\xc3\xb1a'}
# b'147184' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'147187' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'147192' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'147267' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'147285' -> {b'rawdata:Location': b'Lleida, Espa\xc3\xb1a'}
# b'1473' -> {b'rawdata:Location': b'Getxo, Vizcaya, Espa\xc3\xb1a'}
# b'147338' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'147340' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'147391' -> {b'rawdata:Location': b'Vigo, Espa\xc3\xb1a'}
# b'147496' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'147519' -> {b'rawdata:Location': b'Vitoria-Gasteiz Kalea, Bilbao, Espa\xc3\xb1a'}
# b'147561' -> {b'rawdata:Location': b'Barakaldo, Baracaldo, Espa\xc3\xb1a'}
# b'147570' -> {b'rawdata:Location': b'X\xc3\xa0bia, Espa\xc3\xb1a'}
# b'147637' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'147739' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'147740' -> {b'rawdata:Location': b'Campo de Criptana, Espa\xc3\xb1a'}
# b'14778' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'14781' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'14783' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'14785' -> {b'rawdata:Location': b'Castell\xc3\xb3n, Espa\xc3\xb1a'}
# b'14786' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'147866' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'14795' -> {b'rawdata:Location': b'El Guincho, Santa Cruz de Tenerife, Espa\xc3\xb1a'}
# b'147995' -> {b'rawdata:Location': b'Ontinyent, Espa\xc3\xb1a'}
# b'14807' -> {b'rawdata:Location': b'Alzira, Valencia, Espa\xc3\xb1a'}
# b'148093' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'1481' -> {b'rawdata:Location': b'La Rioja - ES'}
# b'14813' -> {b'rawdata:Location': b'Gij\xc3\xb3n, Espa\xc3\xb1a'}
# b'148142' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'148143' -> {b'rawdata:Location': b'Andaluc\xc3\xada, Espa\xc3\xb1a'}
# b'148147' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'148159' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'148197' -> {b'rawdata:Location': b'Almer\xc3\xada, Espa\xc3\xb1a'}
# b'148213' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'148228' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'14838' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'148409' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'148480' -> {b'rawdata:Location': b'Galicia, Espa\xc3\xb1a'}
# b'148486' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'148489' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'148571' -> {b'rawdata:Location': b'Calle de Badaya, 37, Vitoria-Gasteiz, Espa\xc3\xb1a'}
# b'148585' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'148729' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'148739' -> {b'rawdata:Location': b'Castell\xc3\xb3n de la Plana, Espa\xc3\xb1a'}
# b'148816' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'148831' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'14898' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'149000' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'14901' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'149031' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'149041' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'149045' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'149080' -> {b'rawdata:Location': b'Boadilla del Monte, Espa\xc3\xb1a'}
# b'149083' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'14909' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'149112' -> {b'rawdata:Location': b'Sabadell, Espa\xc3\xb1a'}
# b'149120' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'149187' -> {b'rawdata:Location': b'Lanzarote, Espa\xc3\xb1a'}
# b'149194' -> {b'rawdata:Location': b'Sevilla, Sevilla, Espa\xc3\xb1a'}
# b'149234' -> {b'rawdata:Location': b'Sant Lloren\xc3\xa7 de Montgai, Lleida, Espa\xc3\xb1a'}
# b'149248' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'14926' -> {b'rawdata:Location': b'C\xc3\xa1ceres, Espa\xc3\xb1a'}
# b'149265' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'149268' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'149308' -> {b'rawdata:Location': b'Le\xc3\xb3n, Espa\xc3\xb1a'}
# b'149342' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'149344' -> {b'rawdata:Location': b'Valsequillo de Gran Canaria, Espa\xc3\xb1a'}
# b'149406' -> {b'rawdata:Location': b'Le\xc3\xb3n, Espa\xc3\xb1a'}
# b'149541' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'149545' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'1496' -> {b'rawdata:Location': b'Santiago de Compostela, Espa\xc3\xb1a'}
# b'14962' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'14964' -> {b'rawdata:Location': b'Tenerife, Espa\xc3\xb1a'}
# b'149657' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'149669' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'149805' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'149807' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'149814' -> {b'rawdata:Location': b'Navarcles, Espa\xc3\xb1a'}
# b'149834' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'14985' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'149903' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'149975' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'149989' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'150031' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150063' -> {b'rawdata:Location': b'Terrassa, Espa\xc3\xb1a'}
# b'150067' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'150122' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'150127' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'150128' -> {b'rawdata:Location': b'Dosrius, Espa\xc3\xb1a'}
# b'150130' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'150132' -> {b'rawdata:Location': b'Andaluc\xc3\xada, Espa\xc3\xb1a'}
# b'150133' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150148' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150207' -> {b'rawdata:Location': b'Santander, Espa\xc3\xb1a'}
# b'150260' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150261' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150270' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150331' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'15038' -> {b'rawdata:Location': b'Vigo, Espa\xc3\xb1a'}
# b'150393' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'15047' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'150479' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'15048' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'150485' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'15049' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150532' -> {b'rawdata:Location': b'Palma, Baleares, Espa\xc3\xb1a'}
# b'150534' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'150611' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150654' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150748' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'150749' -> {b'rawdata:Location': b'Ronda, Espa\xc3\xb1a'}
# b'150755' -> {b'rawdata:Location': b'Gij\xc3\xb3n, Espa\xc3\xb1a'}
# b'150759' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'150778' -> {b'rawdata:Location': b'Moa\xc3\xb1a, Espa\xc3\xb1a'}
# b'150826' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'150861' -> {b'rawdata:Location': b'Vigo, Espa\xc3\xb1a'}
# b'150890' -> {b'rawdata:Location': b'Arriate, Espa\xc3\xb1a'}
# b'150894' -> {b'rawdata:Location': b'Ronda, M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'150908' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'150999' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151038' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'15104' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151055' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151123' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151140' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'151283' -> {b'rawdata:Location': b'Valverde del Fresno, Espa\xc3\xb1a'}
# b'151289' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'151311' -> {b'rawdata:Location': b'Logro\xc3\xb1o, Espa\xc3\xb1a'}
# b'151399' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151401' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151426' -> {b'rawdata:Location': b'Logro\xc3\xb1o, Espa\xc3\xb1a'}
# b'151446' -> {b'rawdata:Location': b'Logro\xc3\xb1o, Espa\xc3\xb1a'}
# b'151519' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'151522' -> {b'rawdata:Location': b'Rinc\xc3\xb3n de Soto, Espa\xc3\xb1a'}
# b'151524' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'151567' -> {b'rawdata:Location': b'Oviedo, Asturias, Espa\xc3\xb1a'}
# b'151657' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151658' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'151713' -> {b'rawdata:Location': b'Seville, Espa\xc3\xb1a'}
# b'151729' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'151884' -> {b'rawdata:Location': b'Castell\xc3\xb3n de la Plana, Espa\xc3\xb1a'}
# b'151896' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'151924' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'151928' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'151929' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151930' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'151961' -> {b'rawdata:Location': b'Sanl\xc3\xbacar de Barrameda, Espa\xc3\xb1a'}
# b'151973' -> {b'rawdata:Location': b'C\xc3\xa1ceres, Espa\xc3\xb1a'}
# b'151996' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'152001' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'152002' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'152049' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'152068' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'15207' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'152077' -> {b'rawdata:Location': b'Vitoria, Espa\xc3\xb1a'}
# b'152127' -> {b'rawdata:Location': b'Olvera, Espa\xc3\xb1a'}
# b'152132' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'152133' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'152134' -> {b'rawdata:Location': b'Tarrasa, Espa\xc3\xb1a'}
# b'152139' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'152172' -> {b'rawdata:Location': b'Las Palmas, Espa\xc3\xb1a'}
# b'152190' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'15220' -> {b'rawdata:Location': b'Mallorca, Islas Baleares, Espa\xc3\xb1a'}
# b'15225' -> {b'rawdata:Location': b'Valladolid, Espa\xc3\xb1a'}
# b'152261' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'152263' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'152267' -> {b'rawdata:Location': b'Albacete, Espa\xc3\xb1a'}
# b'152268' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'152269' -> {b'rawdata:Location': b'Santa Cruz de Tenerife, Espa\xc3\xb1a'}
# b'152271' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'152272' -> {b'rawdata:Location': b'Asturias, Espa\xc3\xb1a'}
# b'152310' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'152336' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a.'}
# b'152376' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'152378' -> {b'rawdata:Location': b'Castell\xc3\xb3n de la Plana, Espa\xc3\xb1a'}
# b'152381' -> {b'rawdata:Location': b'L\xc3\xa9rida, Espa\xc3\xb1a'}
# b'152408' -> {b'rawdata:Location': b'Pa\xc3\xads Vasco, Espa\xc3\xb1a'}
# b'152409' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'15245' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'152540' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'152561' -> {b'rawdata:Location': b'Santiago de Compostela, Espa\xc3\xb1a'}
# b'152579' -> {b'rawdata:Location': b'Manresa, Espa\xc3\xb1a'}
# b'152599' -> {b'rawdata:Location': b'Badajoz, Espa\xc3\xb1a'}
# b'152615' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'152654' -> {b'rawdata:Location': b'Torrevieja, Espa\xc3\xb1a'}
# b'152655' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'152657' -> {b'rawdata:Location': b'bcn, Espa\xc3\xb1a'}
# b'152713' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'152717' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'152796' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'152811' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'152841' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'15285' -> {b'rawdata:Location': b'Santiago de Compostela, Espa\xc3\xb1a'}
# b'152869' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'15289' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'152970' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153010' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153022' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'153064' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'15312' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153120' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153123' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'153124' -> {b'rawdata:Location': b'Seville, Espa\xc3\xb1a'}
# b'153131' -> {b'rawdata:Location': b'Olvera, Espa\xc3\xb1a'}
# b'15314' -> {b'rawdata:Location': b'Bilbao, Vizcaya, Espa\xc3\xb1a'}
# b'153169' -> {b'rawdata:Location': b'Nar\xc3\xb3n, Espa\xc3\xb1a'}
# b'153216' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'15323' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'153254' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'153276' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'15331' -> {b'rawdata:Location': b'Soto del Real, Madrid, Espa\xc3\xb1a'}
# b'153378' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'153428' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'153463' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'153464' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153483' -> {b'rawdata:Location': b'Galicia, Espa\xc3\xb1a'}
# b'153516' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153526' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153585' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153602' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153667' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'153761' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153762' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'15392' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'153922' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'153924' -> {b'rawdata:Location': b'Bilbao, Bilbao, Espa\xc3\xb1a'}
# b'153938' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'153957' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154019' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154028' -> {b'rawdata:Location': b'Castell\xc3\xb3n de la Plana, Espa\xc3\xb1a'}
# b'15403' -> {b'rawdata:Location': b'Cheste, Val\xc3\xa8ncia, Espa\xc3\xb1a'}
# b'154050' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'154124' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154194' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'154432' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'154467' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'15447' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154473' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'15450' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'154537' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'15455' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'154559' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'154564' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'15459' -> {b'rawdata:Location': b'Tolosa, Espa\xc3\xb1a'}
# b'154672' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154678' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'154783' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'154808' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154843' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'154844' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'154845' -> {b'rawdata:Location': b'Tarragona, Tarragona, Espa\xc3\xb1a'}
# b'154847' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154873' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154920' -> {b'rawdata:Location': b'Donostia, Espa\xc3\xb1a'}
# b'154921' -> {b'rawdata:Location': b'Islas Canarias, Espa\xc3\xb1a'}
# b'154924' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'154965' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'155030' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'155085' -> {b'rawdata:Location': b'Terrassa, Espa\xc3\xb1a'}
# b'155231' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'155239' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'15525' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'155340' -> {b'rawdata:Location': b'Ciudad Real, Espa\xc3\xb1a'}
# b'15543' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'155430' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'155478' -> {b'rawdata:Location': b'Asturias, Espa\xc3\xb1a'}
# b'155533' -> {b'rawdata:Location': b'Palafrugell, Espa\xc3\xb1a'}
# b'155566' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'155567' -> {b'rawdata:Location': b"S'Illot-Cala Morlanda, Espa\xc3\xb1a"}
# b'155605' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'155650' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'155701' -> {b'rawdata:Location': b'Andaluc\xc3\xada, Espa\xc3\xb1a'}
# b'155708' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'155764' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'155771' -> {b'rawdata:Location': b'Manresa, Espa\xc3\xb1a'}
# b'155782' -> {b'rawdata:Location': b'Ciudad Real, Ciudad Real, Espa\xc3\xb1a'}
# b'155797' -> {b'rawdata:Location': b'Badajoz, Espa\xc3\xb1a'}
# b'155832' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'155887' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'155904' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'155912' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'155921' -> {b'rawdata:Location': b'San Sebasti\xc3\xa1n, Espa\xc3\xb1a'}
# b'155936' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'155998' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'156000' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'156005' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'156017' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'156067' -> {b'rawdata:Location': b'Chile Espa\xc3\xb1a, Providencia, Chile'}
# b'156107' -> {b'rawdata:Location': b'Suchs, Espa\xc3\xb1a'}
# b'156112' -> {b'rawdata:Location': b'Gij\xc3\xb3n, Espa\xc3\xb1a'}
# b'15620' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'15621' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'156240' -> {b'rawdata:Location': b'Madrid y Vitoria-Gasteiz, ES'}
# b'156271' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'156279' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'156358' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'156396' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'156441' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'156448' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'156480' -> {b'rawdata:Location': b'Pontevedra, Espa\xc3\xb1a'}
# b'156481' -> {b'rawdata:Location': b'Alicante Centro Ciudad, Alicante (Alacant), Espa\xc3\xb1a'}
# b'156483' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'156495' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'156500' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'156545' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'156639' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'156667' -> {b'rawdata:Location': b'Vic, Espa\xc3\xb1a'}
# b'156740' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'156741' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'156796' -> {b'rawdata:Location': b'Asturias, Espa\xc3\xb1a'}
# b'156880' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'156883' -> {b'rawdata:Location': b'Logro\xc3\xb1o, Espa\xc3\xb1a'}
# b'157135' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'157149' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'157171' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'157210' -> {b'rawdata:Location': b'Palencia, Espa\xc3\xb1a'}
# b'157245' -> {b'rawdata:Location': b'Orihuela, Espa\xc3\xb1a'}
# b'157246' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'157291' -> {b'rawdata:Location': b'Oviedo, Espa\xc3\xb1a'}
# b'157332' -> {b'rawdata:Location': b'Girona, Espa\xc3\xb1a'}
# b'157402' -> {b'rawdata:Location': b'Catalunya, Espa\xc3\xb1a'}
# b'157578' -> {b'rawdata:Location': b'Galicia, Espa\xc3\xb1a'}
# b'157584' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'157686' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'157701' -> {b'rawdata:Location': b'Santander, Espa\xc3\xb1a'}
# b'15775' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'157761' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'157770' -> {b'rawdata:Location': b'Ingenio, Espa\xc3\xb1a'}
# b'157778' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'157807' -> {b'rawdata:Location': b'Matar\xc3\xb3, Espa\xc3\xb1a'}
# b'157853' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'157861' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'15787' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'157897' -> {b'rawdata:Location': b'Canary Islands, Espa\xc3\xb1a'}
# b'157957' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'157962' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'157970' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'158019' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158022' -> {b'rawdata:Location': b'Av. Europa, 10, Coslada, Espa\xc3\xb1a'}
# b'158114' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158135' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'158149' -> {b'rawdata:Location': b'Oviedo, Espa\xc3\xb1a'}
# b'158152' -> {b'rawdata:Location': b'\xc3\x89ibar, Espa\xc3\xb1a'}
# b'158156' -> {b'rawdata:Location': b'Trebujena, Espa\xc3\xb1a'}
# b'158158' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'158188' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'158276' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'158280' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158292' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'158341' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158345' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'158346' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'158385' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'158436' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'158442' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'158444' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158463' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158478' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158501' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'158515' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'15855' -> {b'rawdata:Location': b'Oviedo, Spain, Espa\xc3\xb1a'}
# b'15857' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158583' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'158599' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'15881' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'158823' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'158849' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'158856' -> {b'rawdata:Location': b'Lleida, Espa\xc3\xb1a'}
# b'158864' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'158870' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'158900' -> {b'rawdata:Location': b'Galicia, Espa\xc3\xb1a'}
# b'158918' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159056' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159058' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159108' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'159144' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'159148' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'159163' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159169' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'15917' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159178' -> {b'rawdata:Location': b'Castell\xc3\xb3n de la Plana, Espa\xc3\xb1a'}
# b'15919' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'159229' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159287' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'159302' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159312' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159355' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'15938' -> {b'rawdata:Location': b'Elche, Espa\xc3\xb1a'}
# b'159449' -> {b'rawdata:Location': b'Basque Country, Espa\xc3\xb1a'}
# b'159451' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'159468' -> {b'rawdata:Location': b'Elche, Espa\xc3\xb1a'}
# b'159477' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'159505' -> {b'rawdata:Location': b'Almer\xc3\xada, Espa\xc3\xb1a'}
# b'159522' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159593' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'159613' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'159766' -> {b'rawdata:Location': b'Mollina, Espa\xc3\xb1a'}
# b'159815' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'159819' -> {b'rawdata:Location': b'Albacete, Espa\xc3\xb1a'}
# b'159989' -> {b'rawdata:Location': b'Valladolid, Espa\xc3\xb1a'}
# b'160032' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'160043' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'160047' -> {b'rawdata:Location': b'Pamplona, Espa\xc3\xb1a'}
# b'160070' -> {b'rawdata:Location': b'Catalunya, Espa\xc3\xb1a'}
# b'160079' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'16008' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'160092' -> {b'rawdata:Location': b'Asturias, Espa\xc3\xb1a'}
# b'160134' -> {b'rawdata:Location': b'Ciudad Real, Espa\xc3\xb1a'}
# b'160162' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'160168' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'160197' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'160270' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'160361' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'160502' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'160606' -> {b'rawdata:Location': b'Seville, Espa\xc3\xb1a'}
# b'16066' -> {b'rawdata:Location': b'Vigo, Espa\xc3\xb1a'}
# b'160685' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'160710' -> {b'rawdata:Location': b'Antequera, Espa\xc3\xb1a'}
# b'160797' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'160810' -> {b'rawdata:Location': b'Alcal\xc3\xa1 del Valle, Espa\xc3\xb1a'}
# b'16086' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'160882' -> {b'rawdata:Location': b'Canary Islands, Espa\xc3\xb1a'}
# b'16090' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'160934' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'160943' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'160953' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'160980' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'161003' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'16108' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'161080' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'161084' -> {b'rawdata:Location': b'Sollana, Espa\xc3\xb1a'}
# b'161091' -> {b'rawdata:Location': b'Andaluc\xc3\xada, Espa\xc3\xb1a'}
# b'161110' -> {b'rawdata:Location': b'Burgos, Espa\xc3\xb1a'}
# b'161119' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'161120' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'161221' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'161248' -> {b'rawdata:Location': b'Santa Cruz de Tenerife, Espa\xc3\xb1a'}
# b'161338' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'161360' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'16141' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'16142' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'161443' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'161503' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'161532' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'161596' -> {b'rawdata:Location': b'La Rioja, Espa\xc3\xb1a'}
# b'161615' -> {b'rawdata:Location': b'Pamplona, Espa\xc3\xb1a'}
# b'161665' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'161678' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'16175' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'161788' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'161808' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'161812' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'161821' -> {b'rawdata:Location': b'Almer\xc3\xada, Espa\xc3\xb1a'}
# b'161847' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'16187' -> {b'rawdata:Location': b'Bilbao, Vizcaya, Espa\xc3\xb1a'}
# b'16191' -> {b'rawdata:Location': b'Ciudad Real, Espa\xc3\xb1a'}
# b'161972' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'161975' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'161988' -> {b'rawdata:Location': b'Matar\xc3\xb3, Espa\xc3\xb1a'}
# b'162004' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162012' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'16202' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162020' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'16207' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'162104' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162120' -> {b'rawdata:Location': b'Cantabria, Espa\xc3\xb1a'}
# b'162144' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'162152' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'162167' -> {b'rawdata:Location': b'Santiago de Compostela, Espa\xc3\xb1a'}
# b'162180' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'162195' -> {b'rawdata:Location': b'Oviedo, Espa\xc3\xb1a'}
# b'162220' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162251' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'162272' -> {b'rawdata:Location': b'bcn, Espa\xc3\xb1a'}
# b'162290' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'16232' -> {b'rawdata:Location': b'\xc3\x81vila, Espa\xc3\xb1a'}
# b'162342' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162343' -> {b'rawdata:Location': b'Alhaur\xc3\xadn de la Torre, Espa\xc3\xb1a'}
# b'16236' -> {b'rawdata:Location': b'Mallorca, Islas Baleares, Espa\xc3\xb1a'}
# b'162365' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162406' -> {b'rawdata:Location': b'Seville, Espa\xc3\xb1a'}
# b'162445' -> {b'rawdata:Location': b'Cantabria, Espa\xc3\xb1a'}
# b'162457' -> {b'rawdata:Location': b'Santiago de Compostela, Espa\xc3\xb1a'}
# b'162458' -> {b'rawdata:Location': b'Santiago de Compostela, Espa\xc3\xb1a'}
# b'162478' -> {b'rawdata:Location': b'Vila-real, Espa\xc3\xb1a'}
# b'162510' -> {b'rawdata:Location': b'Gasteiz, Espa\xc3\xb1a'}
# b'162572' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162580' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'162587' -> {b'rawdata:Location': b'Palma, Espa\xc3\xb1a'}
# b'162597' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'162675' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'162698' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'162706' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162708' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'162724' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'162765' -> {b'rawdata:Location': b'Comunidad Valenciana, Espa\xc3\xb1a'}
# b'162798' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'162833' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'162837' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'162842' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'16285' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'162877' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'16295' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'163003' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'163014' -> {b'rawdata:Location': b'Fuengirola, Espa\xc3\xb1a'}
# b'163065' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'163071' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'163129' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'16321' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'163245' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'16326' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'16330' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'163317' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'163335' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'163339' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'163466' -> {b'rawdata:Location': b'Dosrius, Espa\xc3\xb1a'}
# b'163473' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'163477' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'163530' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'163624' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'163658' -> {b'rawdata:Location': b'Corbera de Llobregat, Espa\xc3\xb1a'}
# b'163682' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'163725' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'163745' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'163782' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'163814' -> {b'rawdata:Location': b'Arrecife, Espa\xc3\xb1a'}
# b'163822' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'163831' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'163901' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'16392' -> {b'rawdata:Location': b'Leioa, Vizcaya, Espa\xc3\xb1a'}
# b'163965' -> {b'rawdata:Location': b'Mallorca, Espa\xc3\xb1a'}
# b'16470' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'16480' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'165088' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'165108' -> {b'rawdata:Location': b'C\xc3\xa1ceres, Espa\xc3\xb1a'}
# b'165116' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'165137' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'165203' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'165208' -> {b'rawdata:Location': b'Marbella, Espa\xc3\xb1a'}
# b'16524' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'165249' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'165323' -> {b'rawdata:Location': b'Mallorca, Espa\xc3\xb1a'}
# b'16534' -> {b'rawdata:Location': b'Reus, Espa\xc3\xb1a'}
# b'165418' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'165424' -> {b'rawdata:Location': b'Ciutadella de Menorca, Espa\xc3\xb1a'}
# b'165428' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'165439' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'16544' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'165637' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'165642' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'165648' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'165658' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'165663' -> {b'rawdata:Location': b'Utrera, Espa\xc3\xb1a'}
# b'165677' -> {b'rawdata:Location': b'Montilla, C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'16572' -> {b'rawdata:Location': b'Calle \xc3\x93scar Dom\xc3\xadnguez, 4, Pinto, Espa\xc3\xb1a'}
# b'16578' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'165828' -> {b'rawdata:Location': b'Lucena, Espa\xc3\xb1a'}
# b'165839' -> {b'rawdata:Location': b'Girona, Espa\xc3\xb1a'}
# b'165840' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'165861' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'165933' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'166000' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'166008' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'166018' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'166076' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'166145' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'166146' -> {b'rawdata:Location': b'Albacete, Espa\xc3\xb1a'}
# b'166310' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'166365' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'16639' -> {b'rawdata:Location': b'Jerez de la Frontera, C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'166405' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'16641' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'166503' -> {b'rawdata:Location': b'Lanzarote, Espa\xc3\xb1a'}
# b'166508' -> {b'rawdata:Location': b'Tenerife, Espa\xc3\xb1a'}
# b'166528' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'16655' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'16656' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'166594' -> {b'rawdata:Location': b'Oiartzun, Guip\xc3\xbazcoa, Espa\xc3\xb1a'}
# b'166712' -> {b'rawdata:Location': b'Amposta, Espa\xc3\xb1a'}
# b'166827' -> {b'rawdata:Location': b'Majadahonda, Espa\xc3\xb1a'}
# b'166828' -> {b'rawdata:Location': b'La Orotava, Santa Cruz de Tenerife, Espa\xc3\xb1a'}
# b'167089' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'167090' -> {b'rawdata:Location': b'Santurtzi, Espa\xc3\xb1a'}
# b'16714' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'16716' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'167209' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'167212' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'167214' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'167255' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'167309' -> {b'rawdata:Location': b'Cartagena, Espa\xc3\xb1a'}
# b'167347' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'167354' -> {b'rawdata:Location': b'Santiago de Compostela, Espa\xc3\xb1a'}
# b'167408' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# ...
# b'91319' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'91327' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'91332' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'91403' -> {b'rawdata:Location': b'Malaga, M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'91467' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'91510' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'9156' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'9158' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'91596' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'91612' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'91613' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'91620' -> {b'rawdata:Location': b'Gran Canaria, Espa\xc3\xb1a'}
# b'91625' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'91637' -> {b'rawdata:Location': b'Cartagena, Espa\xc3\xb1a'}
# b'91682' -> {b'rawdata:Location': b'Sant Cugat, Barcelona, Espa\xc3\xb1a'}
# b'91726' -> {b'rawdata:Location': b'Burjassot, Espa\xc3\xb1a'}
# b'91729' -> {b'rawdata:Location': b'Almeria, Almer\xc3\xada, Espa\xc3\xb1a'}
# b'91731' -> {b'rawdata:Location': b'Huelva, Huelva, Espa\xc3\xb1a'}
# b'91744' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'91745' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'91830' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'91918' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'91988' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'91993' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92002' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92143' -> {b'rawdata:Location': b'Mar\xc3\xadn, Pontevedra, Espa\xc3\xb1a'}
# b'92144' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'92149' -> {b'rawdata:Location': b'Lleida, Espa\xc3\xb1a'}
# b'92151' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92152' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'92168' -> {b'rawdata:Location': b'Murcia, Murcia, Espa\xc3\xb1a'}
# b'92179' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'92287' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'92292' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92301' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92416' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'92422' -> {b'rawdata:Location': b'Tarragona, Espa\xc3\xb1a'}
# b'92429' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'92519' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92538' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'92630' -> {b'rawdata:Location': b'Valladolid, Espa\xc3\xb1a'}
# b'92679' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'92755' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'92760' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'92854' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'92855' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92856' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'9286' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92862' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'92869' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92881' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'92899' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92905' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'92967' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'92970' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'92984' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'92989' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'93071' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'93072' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'93078' -> {b'rawdata:Location': b'Oviedo, Espa\xc3\xb1a'}
# b'93079' -> {b'rawdata:Location': b'Barakaldo, Vizcaya, Espa\xc3\xb1a'}
# b'93080' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'9316' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'93213' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'93217' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'93229' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'93288' -> {b'rawdata:Location': b'Gij\xc3\xb3n, Asturias, Espa\xc3\xb1a'}
# b'93357' -> {b'rawdata:Location': b'Sanl\xc3\xbacar de Barrameda, Espa\xc3\xb1a'}
# b'93402' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'93420' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'93427' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'93503' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'93522' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'93529' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'93534' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'93554' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'93631' -> {b'rawdata:Location': b'X\xc3\xa0tiva, Espa\xc3\xb1a'}
# b'93638' -> {b'rawdata:Location': b'San Juan de Palam\xc3\xb3s, Espa\xc3\xb1a'}
# b'93663' -> {b'rawdata:Location': b'Girona, Espa\xc3\xb1a'}
# b'93757' -> {b'rawdata:Location': b'Canary Islands, Espa\xc3\xb1a'}
# b'93764' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'93798' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'93802' -> {b'rawdata:Location': b'Basque Country, Espa\xc3\xb1a'}
# b'93853' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'93864' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'93868' -> {b'rawdata:Location': b'Granada, Espa\xc3\xb1a'}
# b'93881' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'93954' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'93967' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'94021' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'94024' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'94042' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'94048' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'94081' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'94089' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'94110' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'94140' -> {b'rawdata:Location': b'Paterna, Espa\xc3\xb1a'}
# b'9416' -> {b'rawdata:Location': b'Almer\xc3\xada, Espa\xc3\xb1a'}
# b'94198' -> {b'rawdata:Location': b'Ja\xc3\xa9n, Espa\xc3\xb1a'}
# b'94239' -> {b'rawdata:Location': b'Vigo, Espa\xc3\xb1a'}
# b'94253' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'94259' -> {b'rawdata:Location': b'Vigo, Espa\xc3\xb1a'}
# b'94307' -> {b'rawdata:Location': b'Santander, Espa\xc3\xb1a'}
# b'94336' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'94401' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'94403' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'94404' -> {b'rawdata:Location': b'Norte de Espa\xc3\xb1a'}
# b'94417' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'94424' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'94511' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'94645' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'94651' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'9468' -> {b'rawdata:Location': b'M\xc3\xa9ntrida, Toledo, Espa\xc3\xb1a'}
# b'94694' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'94831' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'9487' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'94933' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'95059' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'9509' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'95197' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'95211' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'95245' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'95312' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'95398' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'95440' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'95448' -> {b'rawdata:Location': b'Malaga, M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'95450' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'95465' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'9549' -> {b'rawdata:Location': b'C\xc3\xa1diz, Espa\xc3\xb1a'}
# b'95540' -> {b'rawdata:Location': b'San Feli\xc3\xba de Llobregat, Espa\xc3\xb1a'}
# b'95577' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'95639' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'95648' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'95657' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'95701' -> {b'rawdata:Location': b'Cartagena, Espa\xc3\xb1a'}
# b'95766' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'95854' -> {b'rawdata:Location': b'Girona, Espa\xc3\xb1a'}
# b'95861' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'95900' -> {b'rawdata:Location': b'Le\xc3\xb3n, Espa\xc3\xb1a'}
# b'95942' -> {b'rawdata:Location': b'Santa Cruz de Tenerife, Espa\xc3\xb1a'}
# b'96005' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'96049' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'96052' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'96058' -> {b'rawdata:Location': b'Galicia, Espa\xc3\xb1a'}
# b'96148' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96153' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96169' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96245' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96248' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'96335' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96365' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96369' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96371' -> {b'rawdata:Location': b'Andaluc\xc3\xada, Espa\xc3\xb1a'}
# b'96375' -> {b'rawdata:Location': b'Las Palmas de Gran Canaria, Espa\xc3\xb1a'}
# b'96383' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'96425' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'96505' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96682' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'9672' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'96727' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'96744' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96808' -> {b'rawdata:Location': b'Tenerife, Espa\xc3\xb1a'}
# b'96841' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96860' -> {b'rawdata:Location': b'El Prat de Llobregat, Espa\xc3\xb1a'}
# b'96888' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'9692' -> {b'rawdata:Location': b'Corvera de Asturias, Asturias, Espa\xc3\xb1a'}
# b'9693' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'96979' -> {b'rawdata:Location': b'Alcoy, Espa\xc3\xb1a'}
# b'96994' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97026' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'97071' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'9715' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'97176' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97222' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'97320' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'97322' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97325' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97397' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'97443' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97473' -> {b'rawdata:Location': b'Canary Islands, Espa\xc3\xb1a'}
# b'9748' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97521' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97525' -> {b'rawdata:Location': b'Logro\xc3\xb1o, Espa\xc3\xb1a'}
# b'97540' -> {b'rawdata:Location': b'Huelva, Espa\xc3\xb1a'}
# b'97547' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'97600' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97602' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'97658' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'97713' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'97714' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'97720' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'97726' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97837' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'97854' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97857' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'97882' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'97897' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'97942' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'98057' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'98058' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'9806' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'98060' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'98062' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'98064' -> {b'rawdata:Location': b'Asturias, Espa\xc3\xb1a'}
# b'9807' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'98077' -> {b'rawdata:Location': b'Zaragoza, Espa\xc3\xb1a'}
# b'9809' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'98168' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'98169' -> {b'rawdata:Location': b'Salamanca, Espa\xc3\xb1a'}
# b'98174' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'98223' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'9841' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'98424' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'98444' -> {b'rawdata:Location': b'Vigo, Espa\xc3\xb1a'}
# b'98470' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'98474' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'98485' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'98533' -> {b'rawdata:Location': b'Valladolid, Espa\xc3\xb1a'}
# b'98707' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'98786' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'98807' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'98815' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'98875' -> {b'rawdata:Location': b'Sabadell, Espa\xc3\xb1a'}
# b'98881' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'98901' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'98924' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'98941' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'98980' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'98992' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'98993' -> {b'rawdata:Location': b'Bilbao, Espa\xc3\xb1a'}
# b'99017' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'99034' -> {b'rawdata:Location': b'Tarragona, Espa\xc3\xb1a'}
# b'99077' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'99140' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'99251' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'99270' -> {b'rawdata:Location': b'Burgos, Espa\xc3\xb1a'}
# b'99414' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'99415' -> {b'rawdata:Location': b'Alicante, Alicante, Espa\xc3\xb1a'}
# b'99424' -> {b'rawdata:Location': b'Badajoz, Espa\xc3\xb1a'}
# b'99441' -> {b'rawdata:Location': b'C\xc3\xb3rdoba, Espa\xc3\xb1a'}
# b'99507' -> {b'rawdata:Location': b'M\xc3\xa1laga, Espa\xc3\xb1a'}
# b'99546' -> {b'rawdata:Location': b'Madrid, Espa\xc3\xb1a'}
# b'99650' -> {b'rawdata:Location': b'Murcia, Espa\xc3\xb1a'}
# b'99656' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'99685' -> {b'rawdata:Location': b'Pamplona, Espa\xc3\xb1a'}
# b'99690' -> {b'rawdata:Location': b'Sevilla, Espa\xc3\xb1a'}
# b'99717' -> {b'rawdata:Location': b'A Coru\xc3\xb1a, Espa\xc3\xb1a'}
# b'99720' -> {b'rawdata:Location': b'Linares, Espa\xc3\xb1a'}
# b'99736' -> {b'rawdata:Location': b'Vitoria-Gasteiz, Espa\xc3\xb1a'}
# b'99791' -> {b'rawdata:Location': b'Palma de Mallorca, Espa\xc3\xb1a'}
# b'99797' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'99802' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'99803' -> {b'rawdata:Location': b'Alicante, Espa\xc3\xb1a'}
# b'99808' -> {b'rawdata:Location': b'Espa\xc3\xb1a'}
# b'99869' -> {b'rawdata:Location': b'Barcelona, Espa\xc3\xb1a'}
# b'99904' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}
# b'99948' -> {b'rawdata:Location': b'Valencia, Espa\xc3\xb1a'}

# %% [markdown]
# ## EJERCICIO: Crear una nueva tabla `poststags` que, de forma eficiente, para cada _tag_, liste los `Id` de los posts que utilizan ese _tag_.
#
# *Nota: El código de ejemplo para separar todas las etiquetas del campo Tags de un post está en la sesión 1.*

# %%
# %%bash
#
# create 'poststags'
# disable 'poststags'
# enable 'poststags'
# Out:
# bash: line 2: create: command not found
# bash: line 3: disable: command not found
# bash: line 4: enable: poststags: not a shell builtin
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-153-4620b606c673> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', "\ncreate 'poststags' \ndisable 'poststags' \nenable 'poststags'\n")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"\ncreate 'poststags' \ndisable 'poststags' \nenable 'poststags'\n"' returned non-zero exit status 1.

# %%
with hbasecon.connection() as connection:
  tags = connection.table("tags")
  doc_tags = tags.scan(limit=20, columns=[b"rawdata:TagName"])
  for key,data in doc_tags:
    print(key, "->", data)
    posts = connection.table("posts")
# Out:
# b'1' -> {b'rawdata:TagName': b'.net'}
# b'10' -> {b'rawdata:TagName': b'karma-jasmine'}
# b'100' -> {b'rawdata:TagName': b'dukescript'}
# b'1000' -> {b'rawdata:TagName': b'buscador'}
# b'1002' -> {b'rawdata:TagName': b'mapsforge'}
# b'1004' -> {b'rawdata:TagName': b'constraints'}
# b'1005' -> {b'rawdata:TagName': b'snapkit'}
# b'1007' -> {b'rawdata:TagName': b'delphi-2010'}
# b'1009' -> {b'rawdata:TagName': b'webview'}
# b'101' -> {b'rawdata:TagName': b'admob'}
# b'1010' -> {b'rawdata:TagName': b'scrapy'}
# b'1011' -> {b'rawdata:TagName': b'adobe-muse'}
# b'1013' -> {b'rawdata:TagName': b'regsvr32'}
# b'1018' -> {b'rawdata:TagName': b'oracle-sqldeveloper'}
# b'1020' -> {b'rawdata:TagName': b'css-transform'}
# b'1021' -> {b'rawdata:TagName': b'volatile'}
# b'1024' -> {b'rawdata:TagName': b'back-button'}
# b'1028' -> {b'rawdata:TagName': b'parsear'}
# b'103' -> {b'rawdata:TagName': b'funciones'}
# b'1030' -> {b'rawdata:TagName': b'webview-android'}

# %% [markdown]
# ## EJERCICIO: Crear una nueva tabla `userstags` que, de forma eficiente, para cada _tag_, liste los `Id` de los usuarios que han escrito posts de ese _tag_.
#
# *Nota: El código de ejemplo para separar todas las etiquetas del campo Tags de un post está en la sesión 1.*

# %% [markdown]
# ## EJERCICIO: Construya una tabla (de la forma más eficiente) que sirva para, dados un ID de usuario que pregunta y un ID de otro usuario que responde, se pueda decir (en orden constante) si forman una pareja al estilo de la RQ4. Con esa tabla, responder a la RQ4.
