# %% [markdown]
# # Sesión 3 - Scrapy - Ejemplo Crawling JSON-LD (ElMundo)

# %% [markdown]
# ## Apartado 1.1 Crawler de El Mundo extrayendo JSON-LD
# En el ejemplo siguiente definimos un crawler en Scrapy para extraer noticias de los metadatos de las páginas web.
# El Mundo y otros periódicos publican metadatos en formato JSON-LD (https://json-ld.org/) que permite obtener información estructurada de las webs. En este caso, tendremos que obtener esos objetos JSON-LD y extraer su información en el formato de noticia (https://schema.org/NewsArticle) publicado en Schema.org
#
# ** Existen librerías de Python para trabajar directamente con JSON-LD

# %%
# !pip3 install -U scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (2.11.2)
# Requirement already satisfied: Twisted>=18.9.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (24.7.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (43.0.1)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (1.9.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (24.2.1)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (1.7.0)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (24.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (2.2.1)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (7.1.0)
# Requirement already satisfied: protego>=0.1.15 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (0.3.1)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (0.9.0)
# Requirement already satisfied: setuptools in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (65.5.0)
# Requirement already satisfied: packaging in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (24.1)
# Requirement already satisfied: tldextract in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (5.1.2)
# Requirement already satisfied: lxml>=4.4.1 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (5.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (0.7.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=36.0.0->scrapy) (1.17.1)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from service-identity>=18.1.0->scrapy) (24.2.0)
# Requirement already satisfied: pyasn1 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.6.1)
# Requirement already satisfied: pyasn1-modules in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.4.1)
# Requirement already satisfied: automat>=0.8.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (24.7.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\x542ua\appdata\roaming\python\python311\site-packages (from Twisted>=18.9.0->scrapy) (4.12.2)
# Requirement already satisfied: idna in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from tldextract->scrapy) (3.10)
# Requirement already satisfied: requests>=2.1.0 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from tldextract->scrapy) (2.32.3)
# Requirement already satisfied: requests-file>=1.4 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from tldextract->scrapy) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from tldextract->scrapy) (3.16.1)
# Requirement already satisfied: pycparser in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\x542ua\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2024.8.30)

# %%
import scrapy
import sys
import json
import locale
import time
import random
from bs4 import BeautifulSoup

class ElMundoSpider (scrapy.Spider):

    #Es obligatorio poner un nombre
    name = 'elmundo'

    #Ponemos que el dominio que está permitido es el de la página y no vamos a irnos fuera de la misma
    allowed_domains = ['www.elmundo.es']

    start_urls = ['https://www.elmundo.es/']

    # para evitar que el sitio te bloquee por usar scrapy es interesante cambiar el USER_AGENT
    # El user agent por defecto de Scrapy cuando hace una petición es
    # Scrapy/VERSION (+https://scrapy.org)
    custom_settings = {
        'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
    }

    def parse (self, response):
      """
      @inherit

      @param self
      @param response
      """

      # Obtenemos la URL de la web que estamos procesando
      url = str(response.request.url).strip()

      # Obtenemos usando CSS la parte donde está definido el JSON-LD en la web
      for item in response.css('script[type=\"application/ld+json\"]'):
        data = json.loads(item.css('::text').get())
        # Procesamos aquí los datos
        # RELLENAR
        if "headline" in data:
            title = data["headline"]
            content = data["description"]
            date = data["datePublished"]
            
            if url :

                print ("-------------------------")
                print (url)
                print (title)
                print (content)
                print (date)
                print ("-------------------------")

                data = {
                    'url' : url,
                    'title': title,
                    'content': content,
                    'date': date
                }

                #Creamos para cada item un fichero json y para ello obtenemos un número aleatorio.
                filename = str(random.random()).replace(".","") + ".json"

                # Guardamos el documento si tiene contenido y título
                if content and title:
                    with open ('elmundo/' + filename, 'w') as f:
                        json.dump (data, f, indent = 4)

        # Por último, miramos distintos enlaces que existan en la web (en este caso todos los de la etiqueta <a>)
        url_in_current_document = response.css ('a')
        for next_page in url_in_current_document:
            # Por cada enlace ejecutamos el mismo parse
            url = str(next_page.css("a::attr(href)").get())
            if "www.elmundo.es" in url:
                yield response.follow (next_page, self.parse)

# %% [markdown]
# ## Apartado 1.2
# Para poder lanzar el Spider necesitamos que ejecutar el siguiente código donde se configuará y lanzará el proceso.
# Hay que hacer notar que solamente se puede lanzar un proceso por cada sesión en Jupyter notebook es por eso por lo que se recomienda exportar el código en un script de Python .py para poder ejecutarlo desde la línea de comandos.

# %%
import os
import scrapy
from scrapy.crawler import CrawlerProcess

# Creamos un proceso de Crawler podemos poner distintas settings que están definidas en la documentación.
# Entre ellas podemos ocular los logs del proceso de Crawling.
process = CrawlerProcess(settings={
    "LOG_ENABLED": False,
    # Used for pipeline 1
})

# Como se ha definido anteriormente en el RSSCrawler, los ficheros se van a almacenar en la carpeta "rss"
# Comprobamos que existe la carpeta y si no existe la creamos
if (not os.path.exists('elmundo')):
    os.mkdir('elmundo')

# Creamos el proceso con el RSSSpider
process.crawl(ElMundoSpider)
# Ejecutamos el Crawler
process.start()
# Out:
# -------------------------
# https://www.elmundo.es/espana/2024/10/17/6710b247e9cf4ad2318b458d.html
# Alvise denuncia un &quot;intento de detención ilegal&quot; de la Guardia Civil anoche mientras estaba alojado en una casa rural en Bustarviejo (Madrid)
# Cinco agentes de la Guardia Civil se personaron anoche en el lugar en el que se encontraba Alvise Pérez para intentar &quot;ejecutar una orden de detención&quot; contra él,...
# 2024-10-17T06:55:53Z
# -------------------------
# -------------------------
# https://www.elmundo.es/cultura/musica/2024/10/17/6710b8cce4d4d8197b8b4590.html
# La familia de Liam Payne: &quot;Lo recordaremos por su alma amable, divertida y valiente&quot;
# La trágica muerte de Liam Payne a los 31 años en Buenos Aires ha causado un gran impacto en el Reino Unido, donde era tremendamente popular como la voz y el &quot;alma&quot; de...
# 2024-10-17T07:33:31Z
# -------------------------
# -------------------------
# https://www.elmundo.es/madrid/2024/10/17/670ff764fdddff4e2f8b460f.html
# El extraño crimen del taxista Isidro, apuñalado &quot;sin mediar palabra&quot; a las puertas del hospital tras 97 minutos de carrera con su asesino: &quot;Me ha matado&quot;
# 2024-03-25T09:56:27Z
# -------------------------
# -------------------------
# https://www.elmundo.es/como/2024/01/03/6595866ee9cf4abe258b4591.html
# Calendario laboral de España 2024: días festivos y puentes
# El calendario laboral 2024 de España publicado en el BOE registra ocho días festivos comunes en todo el territorio. A estos días festivos hay que añadir otros cuatro festivos...
# 2024-01-03T16:08:56Z
# -------------------------
# -------------------------
# https://www.elmundo.es/espana/2024/09/26/66f460aefdddff5cbc8b4590.html
# Alvise prometió a sus fieles que no tenía &quot;más relación&quot; con el denunciante el día que presentaba decenas de pruebas
# A las seis de la tarde del pasado jueves 19 de septiembre, Alvise Pérez desmintió las informaciones que le vinculaban con Madeira Invest Club, el negocio que presuntamente...
# 2024-09-26T00:05:05Z
# -------------------------
# -------------------------
# https://www.elmundo.es/espana/2024/10/05/6700285f21efa04c2e8b458c.html
# El presunto financiador irregular de Alvise planteaba un intercambio comercial de miles de euros: &quot;Cuenta con el centenar, lo pongo para ganar más en el futuro&quot;
# &laquo;Todo lo que respecte al centenar [de miles de euros] cuenta con ello&raquo;. &laquo;Respecto al tema de la aportación, que tú decías que vas a necesitar cierta liquidez...
# 2024-10-04T23:31:49Z
# -------------------------
# -------------------------
# https://www.elmundo.es/metropoli/2024/10/17/670fec30e9cf4a64078b458c.html
# El restaurante de lujo con barra de caviar donde suenan los chistes de Chiquito de la Calzada en el cuarto de baño
# Un bar, un bistró, un mostrador de caviar, una coctelería, una vermutería, un reservado, una barra castiza, un restaurante exclusivo, un clandestino, un piano bar, un club, un...
# 2024-10-16T22:26:15Z
# -------------------------
# -------------------------
# https://www.elmundo.es/como/2024/06/10/6666b692fc6c83be1d8b457c.html
# Estos son los 61 eurodiputados que representarán a España en el Parlamento Europeo
# Con los votos de las elecciones europeas del 9-J toma forma una nueva legislatura en el Parlamento Europeo. A España le corresponden 61 eurodiputados, que finalmente se...
# 2024-06-10T09:32:55Z
# -------------------------
# -------------------------
# https://www.elmundo.es/elecciones/elecciones-europeas/2024/06/10/6666376cfc6c83f10c8b457c.html
# ¿Qué han votado en tu pueblo? Los resultados de las elecciones europeas, municipio por municipio
# Pedro Sánchez no podrá darse &quot;el gustazo&quot;, como era su deseo, de decir que el PSOE ha vencido al Partido Popular en estas elecciones europeas: el PP ha sido el vencedor...
# 2024-06-09T23:22:28Z
# -------------------------
# -------------------------
# https://www.elmundo.es/como/2024/06/10/6666a0fefdddff862e8b45a6.html
# Quién ha ganado las Elecciones Europeas 2024 en España
# Este domingo 9 de junio, millones de ciudadanos europeos fueron llamados a las urnas para votar en las Elecciones Europeas 2024, que eligen a los representantes en el Parlamento...
# 2024-06-10T06:45:51Z
# -------------------------
# -------------------------
# https://www.elmundo.es/elecciones/elecciones-europeas/2024/06/10/6666f35ee85ece95438b4588.html
# El PP niega a Alvise la condición de &quot;interlocutor&quot; y se lo endosa a Abascal: &quot;Es una guerra electoral entre ellos&quot;
# El PP hace un balance muy positivo de las elecciones europeas. Los populares creen que su victoria, con el 34% de los votos y cuatro puntos más que el PSOE, no es que sea clara,...
# 2024-06-10T12:39:14Z
# -------------------------
# -------------------------
# https://www.elmundo.es/espana/2024/10/16/670fd457e4d4d824628b4578.html
# Tres socios de Sánchez se alían con el PP para reprobar al ministro Óscar Puente en el Congreso por el &quot;caos&quot; de los trenes
# El ministro de Transportes, Óscar Puente, ha sido reprobado por el Congreso de los Diputados después de que hasta tres socios parlamentarios de Pedro Sánchez se hayan aliado con...
# 2024-10-16T14:57:31Z
# -------------------------
# -------------------------
# https://www.elmundo.es/espana/2024/10/16/670ff37e21efa09d238b45ab.html
# La imputación del fiscal general culmina el deterioro institucional
# Álvaro García Ortiz se convirtió ayer en el primer fiscal general del Estado imputado en la historia de España. El Tribunal Supremo notificó a primera hora la apertura de una...
# 2024-10-16T20:50:56Z
# -------------------------
# -------------------------
# https://www.elmundo.es/espana/2024/09/09/66def918e9cf4a573c8b459a.html
# El juez del &apos;caso Koldo&apos; rechaza  &quot;en este momento&quot; pedir al Supremo que impute al ex ministro Ábalos
# El juez que instruye el caso Koldo ha rechazado elevar &quot;en este momento&quot; una exposición razonada al Tribunal Supremo (TS) para que se valore la imputación del ex...
# 2024-09-09T13:54:26Z
# -------------------------
# -------------------------
# https://www.elmundo.es/madrid/2024/09/09/66deeedf21efa01b348b4584.html
# El Supremo pregunta a la Fiscalía si imputa a García Ortiz por la filtración sobre el novio de Ayuso
# Cuenta atrás para la decisión del Tribunal Supremo sobre el futuro procesal del fiscal general del Estado, Álvaro García Ortiz. La Sala de lo Penal ha pedido a la Fiscalía un...
# 2024-09-09T13:03:28Z
# -------------------------
# -------------------------
# https://www.elmundo.es/espana/2024/10/16/670ff5e2e85ece0e458b4594.html
# El bulo que García Ortiz sigue agitando contra EL MUNDO
# La reacción del fiscal general del Estado que ha desembocado en su imputación por revelación de secretos tiene su origen en la información veraz que publicó EL MUNDO a las...
# 2024-10-16T20:50:34Z
# -------------------------
# -------------------------
# https://www.elmundo.es/elecciones/elecciones-europeas/2024/06/10/6667383f21efa0040b8b45a1.html
# Sánchez traslada ya a su núcleo duro la &quot;preocupación&quot; por los resultados en Andalucía y Madrid
# El análisis territorial que se ha hecho en el PSOE de las elecciones europeas celebradas este domingo -que a su vez se habían planteado en clave nacional- ha dejado al aire la...
# 2024-06-10T20:53:31Z
# -------------------------
# -------------------------
# https://www.elmundo.es/espana/2024/10/16/670ff4e1fdddffc8288b45c6.html
# Fiscales acusan a García Ortiz de &quot;anteponer sus intereses personales a los de la institución&quot; al aferrarse al cargo tras su imputación
# La imputación del fiscal general del Estado, Álvaro García Ortiz, ha sumido en el desánimo a los miembros de la Carrera Fiscal que miran con tristeza cómo el prestigio de la...
# 2024-10-16T20:50:46Z
# -------------------------
# -------------------------
# https://www.elmundo.es/internacional/2024/09/10/66e01371fc6c83dd328b4584.html
# Starmer pone en la calle a 1.700 presos por falta de espacio en las cárceles británicas
# Unos 1.700 presos británicos serán puestos en libertad el martes por falta de espacio en las cárceles de Inglaterra y Gales, que la semana registraron un récord de ocupación...
# 2024-09-10T09:41:38Z
# -------------------------
