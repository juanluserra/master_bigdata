# %%
# !source .venv/bin/activate

# %%
# !ls *patentes*/
# Out:
# patentes/:
# apat63_99.txt  cite75_99.txt  country_codes.txt
#
# patentes-mini/:
# apat63_99.txt  cite75_99.txt  country_codes.txt

# %%
# !python3 citingpatents1.py patentes-mini/cite75_99.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/citingpatents1.luser.20250102.160903.963851
# Running step 1 of 1...
# job output is in /tmp/citingpatents1.luser.20250102.160903.963851/output
# Streaming final output from /tmp/citingpatents1.luser.20250102.160903.963851/output...
# 4510224	5166018
# 4510228	5236802
# 4510484	5600301
# 4510489	5015953
# 4510651	5271606
# 4511195	4686428
# 4511325	4739713
# 4511811	5874337
# 4511975	5694534
# 4512210	5787761
# 4512298	5537959
# 4512764	5643205
# 4512765	5342394
# 4512841	4647361
# 4512870	5192417
# 4513374	4725987
# 4513643	4819519
# 4514435	4565591
# 4514796	5204942
# 4514804	4755966
# 4514959	4967540
# 4515376	5052695
# 4515602	5474582
# 4515784	5100657
# 4515829	4948630
# 4515994	5479157
# 4516152	5321504
# 4516272	5930014
# 4516310	4630354
# 4516568	5637076
# 4516784	4850829
# 4517559	4689446
# 4518388	4868024
# 4518651	5690853
# 4518655	5480725
# ...

# %%
# !python3 citationnumberbypatent_chained2.py patentes-mini/cite75_99.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/citationnumberbypatent_chained2.luser.20250102.160906.858477
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /tmp/citationnumberbypatent_chained2.luser.20250102.160906.858477/output
# Streaming final output from /tmp/citationnumberbypatent_chained2.luser.20250102.160906.858477/output...
# 4511195,1
# 4511325,1
# 4511811,1
# 4511975,1
# 4512210,1
# 4512298,1
# 4512764,1
# 4512765,1
# 4512841,1
# 4512870,1
# 4513374,1
# 4513643,1
# 4514435,1
# 4514796,1
# 4514804,1
# 4514959,1
# 4515376,1
# 4515602,1
# 4515784,1
# 4515829,1
# 4515994,1
# 4516152,1
# 4516272,1
# 4516310,1
# 4516568,1
# 4516784,1
# 4517559,1
# 4518388,1
# 4518651,1
# 4518655,1
# 4518961,1
# 4519078,1
# 4519087,1
# 4519504,1
# 4519559,1
# 4519792,1
# 4520929,1
# 4521194,1
# 4521413,1
# 4522048,1
# 4522067,1
# 4522145,1
# 4522206,1
# 4522274,1
# 4522972,1
# 4523228,1
# 4523428,1
# ...

# %%
# !cp -f patentes-mini/country_codes.txt /home/luser

# %%
# !python3 countrypatents3.py patentes-mini/apat63_99.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/countrypatents3.luser.20250102.163005.552083
# Running step 1 of 1...
# job output is in /tmp/countrypatents3.luser.20250102.163005.552083/output
# Streaming final output from /tmp/countrypatents3.luser.20250102.163005.552083/output...
# United States	3857764,1974
# United States	5562283,1996
# United States	4229799,1980
# France	4253849,1981
# United States	4664387,1987
# United States	5545850,1996
# Switzerland	4112673,1978
# Cuba	4624249,1986
# United States	5948000,1999
# Great Britain (UK)	5836347,1998
# United States	5358201,1994
# Switzerland	4407882,1983
# United States	5522486,1996
# United States	5441481,1995
# Germany	5765291,1998
# United States	4180596,1979
# Japan	4126731,1978
# Germany	5796548,1998
# United States	4639255,1987
# United States	5613495,1997
# United States	4289799,1981
# Japan	3894389,1975
# United States	3361037,1968
# ...

# %%
# !python3 sortsecundario4.py patentes-mini/apat63_99.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# ignoring partitioner keyword arg (requires real Hadoop): 'org.apache.hadoop.mapred.lib.KeyFieldBasedPartitioner'
# Creating temp directory /tmp/sortsecundario4.luser.20250102.163420.479132
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /tmp/sortsecundario4.luser.20250102.163420.479132/output
# Streaming final output from /tmp/sortsecundario4.luser.20250102.163420.479132/output...
# United States	1989 -> 449
# United States	1990 -> 459
# United States	1991 -> 443
# Germany	1982 -> 26
# Germany	1983 -> 42
# Germany	1984 -> 47
# Germany	1985 -> 42
# Germany	1986 -> 49
# Germany	1987 -> 54
# Germany	1988 -> 48
# Germany	1989 -> 42
# Germany	1990 -> 38
# Germany	1991 -> 41
# Germany	1992 -> 34
# Germany	1993 -> 36
# Germany	1994 -> 44
# Germany	1995 -> 38
# Germany	1996 -> 27
# Germany	1997 -> 29
# Germany	1998 -> 45
# Germany	1999 -> 44
# Great Britain (UK)	1963 -> 2
# ...
